# %%
import pandas as pd
import numpy as np
import json
from parsivar import Normalizer
import hazm
from collections import defaultdict, Counter
from tqdm.notebook import tqdm_notebook
from transformers import AutoTokenizer, AutoModel
from datasets import Dataset, DatasetDict
from collections import Counter, defaultdict
from sklearn.model_selection import train_test_split
import torch
from torch import nn
from sklearn.metrics import accuracy_score
import sqlite3
import csv
import matplotlib.pyplot as plt

# %%
class MyNormalizer:
    def __init__(self):
        self.parsivar_normalizer = Normalizer(
            statistical_space_correction=True,
            half_space_char=" ",
            pinglish_conversion_needed=True,
        )
        self.hazm_normalizer = hazm.Normalizer(
            remove_extra_spaces=True,
            persian_numbers=True,
            persian_style=True,
            punctuation_spacing=False,
            remove_diacritics=True,
            affix_spacing=False,
            token_based=True,
        )

    def normilize(self, txt):
        return self.hazm_normalizer.normalize(
            self.parsivar_normalizer.normalize(
                txt.replace("\n", " ").replace("\u200c", " ").lower().strip()
            )
        )

# %%
class JsonFileIterator:
    def __init__(self, path):
        self.path = path
        self.f = open(path, "r")
        self.i = 0
        self.length = self.counter_lines()

    def __iter__(self):
        return self

    def __next__(self):
        line = self.f.readline()
        if not line:
            # End of file
            self.f.close()
            raise StopIteration
        self.i += 1
        return json.loads(line)

    def counter_lines(self):
        with open(self.path, "r") as f1:
            return sum(1 for _ in f1)

    def __len__(self):
        return self.length

# %%
normalizer = MyNormalizer()
search_data = JsonFileIterator("./data/torob-search-data_v1.jsonl")
product_res = dict()
clicked_result = dict()
queries = dict()

for search in tqdm_notebook(search_data):
    for pid in search["result"]:
        if product_res.get(pid, -1) == -1:
            product_res[pid] = 1
        else:
            product_res[pid] += 1
    for pid in search["clicked_result"]:
        if clicked_result.get(pid, -1) == -1:
            clicked_result[pid] = 1
        else:
            clicked_result[pid] += 1
    raw_query = search["raw_query"]
    normalized_query = normalizer.normilize(raw_query)
    if queries.get(normalized_query, -1) == -1:
        queries[normalized_query] = 1
    else:
        queries[normalized_query] += 1
# Out:
#   0%|          | 0/2499901 [00:00<?, ?it/s]

# %%
# average of clicked result
print("average of clicked result: ", sum(clicked_result.values()) / len(clicked_result))

# %%
agg_searches = defaultdict(
    lambda: dict(
        results=Counter(),
        clicks=Counter(),
    )
)

search_data = JsonFileIterator("./torob-search-data_v1.jsonl")
print("Aggregating searches based on raw query...")

for search in tqdm_notebook(search_data):
    raw_query = search['raw_query']
    normalized_query = normalizer.normilize(raw_query)

    if queries[normalized_query] > 50:
        results = search['result'][:np.max(search['clicked_rank']) + 8]
        clicked_results = search['clicked_result']
        agg_searches[normalized_query]['results'].update(results)
        agg_searches[normalized_query]['clicks'].update(clicked_results)

# %%
len(queries)
# Out:
# 176427

# %%
len()

# %%
# average click
avg_click = 0
for query in agg_searches:
    avg_click += sum(agg_searches[query]['clicks'].values())

# %%
test_data = JsonFileIterator("./data/test-offline-data_v1.jsonl")
with open('predictions.txt', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    for idx , row in enumerate(tqdm_notebook(test_data)):
        result_not_ranked = row["result_not_ranked"]
        result_list = []
        for res in result_not_ranked:
            # score is (click + 1 / impression + avg(clicks)) * (click)
            score = (clicked_result.get(res , 0) + 1) / (product_res.get(res , 0) + avg_click) * clicked_result.get(res , 0)
            item = (res ,score)
            result_list.append(item)
        sorted_list = sorted(result_list, key=lambda x: x[1] , reverse=True)
        writer.writerow([x[0] for x in sorted_list])
# Out:
#   0%|          | 0/23140 [00:00<?, ?it/s]

# %%
# get difference of two files
def get_diff(file1, file2):
    '''get difference of two files'''

# %%
normalizer = MyNormalizer()
search_data = JsonFileIterator("./data/torob-search-data_v1.jsonl")
product_res = dict()
clicked_result = dict()
queries = dict()
num_products = 0  # number of products in each search
num_searches = 0  # number of searches
num_clicks = 0  # number of clicks
num_impressions = 0  # number of impressions

for search in tqdm_notebook(search_data):
    num_products += len(search["result"])
    num_searches += 1
    
    for pid in search["result"]:
        if product_res.get(pid, -1) == -1:
            product_res[pid] = 1
        else:
            product_res[pid] += 1
    
    for pid in search["clicked_result"]:
        if clicked_result.get(pid, -1) == -1:
            clicked_result[pid] = 1
        else:
            clicked_result[pid] += 1
        num_clicks += 1
    
    raw_query = search["raw_query"]
    normalized_query = normalizer.normilize(raw_query)
    if queries.get(normalized_query, -1) == -1:
        queries[normalized_query] = 1
    else:
        queries[normalized_query] += 1
    
    num_impressions += len(search["result"])
    
agg_ctr = (num_clicks + 1) / (num_impressions + num_products)

print(f"Aggregated Clicks: {num_clicks}")
print(f"Aggregated Impressions: {num_impressions}")
print(f"Aggregated CTR: {agg_ctr}")
# Out:
#   0%|          | 0/2499901 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_930098/642310747.py in <module>
#      20
#      21     for pid in search["clicked_result"]:
# ---> 22         if clicked_result.get(pid, -1) == -1:
#      23             clicked_result[pid] = 1
#      24         else:
#
# KeyboardInterrupt:

# %%
normalizer = MyNormalizer()
search_data = JsonFileIterator("./data/torob-search-data_v1.jsonl")
product_res = dict()l
clicked_result = dict()
queries = dict()
impressions = dict()
ctr = dict()

for search in tqdm_notebook(search_data):
    # update product_res dictionary
    for pid in search["result"]:
        if pid is not None:
            product_res[pid] = product_res.get(pid, 0) + 1
            
    # update clicked_result dictionary
    for pid in search["clicked_result"]:
        if pid is not None:
            clicked_result[pid] = clicked_result.get(pid, 0) + 1
    
    # update queries dictionary
    raw_query = search["raw_query"]
    normalized_query = normalizer.normilize(raw_query)
    queries[normalized_query] = queries.get(normalized_query, 0) + 1
    
    # update impressions dictionary
    for pid in search["result"]:
        if pid is not None:
            if pid not in impressions:
                impressions[pid] = {"count": 1, "query_count": {normalized_query: 1}}
            else:
                impressions[pid]["count"] += 1
                if normalized_query not in impressions[pid]["query_count"]:
                    impressions[pid]["query_count"][normalized_query] = 1
                else:
                    impressions[pid]["query_count"][normalized_query] += 1
    
    # update ctr dictionary
    for pid in search["clicked_result"]:
        if pid is not None:
            if pid not in ctr:
                ctr[pid] = {"click_count": 1, "impression_count": 1 + len(search["result"])}
            else:
                ctr[pid]["click_count"] += 1
                ctr[pid]["impression_count"] += 1

# calculate aggregated ctr
agg_ctr = dict()
for pid in impressions:
    agg_ctr[pid] = (clicked_result.get(pid, 0) + 1) / (impressions[pid]["count"] + len(queries))
# Out:
#   0%|          | 0/2499901 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_930098/1050712145.py in <module>
#      29                 impressions[pid] = {"count": 1, "query_count": {normalized_query: 1}}
#      30             else:
# ---> 31                 impressions[pid]["count"] += 1
#      32                 if normalized_query not in impressions[pid]["query_count"]:
#      33                     impressions[pid]["query_count"][normalized_query] = 1
#
# KeyboardInterrupt:

# %%
# product_res = dict()
# product_res
# clicked_result = dict()
# clicked_result
# queries = dict()
# queries
# impressions = dict()
# impressions
# ctr = dict()
# ctr
# Out:
# {9457219: {'click_count': 1, 'impression_count': 31},
#  3147253: {'click_count': 12, 'impression_count': 32},
#  7135387: {'click_count': 2, 'impression_count': 22},
#  900897: {'click_count': 19, 'impression_count': 89},
#  2931230: {'click_count': 10, 'impression_count': 80},
#  31302: {'click_count': 4, 'impression_count': 74},
#  7660686: {'click_count': 1, 'impression_count': 71},
#  5901997: {'click_count': 1, 'impression_count': 71},
#  2376830: {'click_count': 1, 'impression_count': 71},
#  2383125: {'click_count': 1, 'impression_count': 71},
#  3852139: {'click_count': 3, 'impression_count': 75},
#  9614943: {'click_count': 4, 'impression_count': 24},
#  7088803: {'click_count': 28, 'impression_count': 48},
#  2912003: {'click_count': 55, 'impression_count': 95},
#  6666498: {'click_count': 8, 'impression_count': 118},
#  1913648: {'click_count': 3, 'impression_count': 143},
#  2498914: {'click_count': 3, 'impression_count': 23},
#  707374: {'click_count': 194, 'impression_count': 214},
#  9280877: {'click_count': 15, 'impression_count': 35},
#  6660687: {'click_count': 76, 'impression_count': 96},
#  7873758: {'click_count': 1, 'impression_count': 25},
#  6661826: {'click_count': 23, 'impression_count': 43},
#  983448: {'click_count': 79, 'impression_count': 99},
#  5270520: {'click_count': 4, 'impression_count': 14},
#  6362392: {'click_count': 1, 'impression_count': 31},
#  6627951: {'click_count': 2, 'impression_count': 32},
#  9084181: {'click_count': 2, 'impression_count': 32},
#  5216068: {'click_count': 1, 'impression_count': 31},
#  2059562: {'click_count': 1, 'impression_count': 31},
#  5253928: {'click_count': 1, 'impression_count': 31},
#  6459452: {'click_count': 1, 'impression_count': 151},
#  3651802: {'click_count': 1, 'impression_count': 151},
#  2333771: {'click_count': 1, 'impression_count': 151},
#  4725010: {'click_count': 10, 'impression_count': 30},
#  9709063: {'click_count': 6, 'impression_count': 26},
#  3695989: {'click_count': 44, 'impression_count': 54},
#  1227966: {'click_count': 1, 'impression_count': 11},
#  700908: {'click_count': 1, 'impression_count': 11},
#  4971820: {'click_count': 1, 'impression_count': 11},
#  9647537: {'click_count': 1, 'impression_count': 11},
#  7653868: {'click_count': 5, 'impression_count': 77},
#  6152981: {'click_count': 2, 'impression_count': 74},
#  1908578: {'click_count': 11, 'impression_count': 31},
#  633352: {'click_count': 142, 'impression_count': 252},
#  4783805: {'click_count': 34, 'impression_count': 144},
#  6046855: {'click_count': 12, 'impression_count': 32},
#  6737881: {'click_count': 1, 'impression_count': 25},
#  665285: {'click_count': 1, 'impression_count': 61},
#  1372130: {'click_count': 1, 'impression_count': 61},
#  6601163: {'click_count': 1, 'impression_count': 61},
#  5791884: {'click_count': 1, 'impression_count': 41},
#  6082935: {'click_count': 2, 'impression_count': 26},
#  7179958: {'click_count': 36, 'impression_count': 56},
#  7071587: {'click_count': 32, 'impression_count': 62},
#  8384532: {'click_count': 34, 'impression_count': 64},
#  2752702: {'click_count': 8, 'impression_count': 38},
#  6773023: {'click_count': 8, 'impression_count': 18},
#  2662052: {'click_count': 1, 'impression_count': 241},
#  9465383: {'click_count': 1, 'impression_count': 241},
#  1896213: {'click_count': 68, 'impression_count': 88},
#  951011: {'click_count': 13, 'impression_count': 33},
#  2340062: {'click_count': 36, 'impression_count': 66},
#  4247858: {'click_count': 4, 'impression_count': 34},
#  3488817: {'click_count': 5, 'impression_count': 35},
#  6107545: {'click_count': 3, 'impression_count': 13},
#  3231839: {'click_count': 119, 'impression_count': 129},
#  9751734: {'click_count': 12, 'impression_count': 92},
#  2478782: {'click_count': 23, 'impression_count': 133},
#  6681024: {'click_count': 71, 'impression_count': 81},
#  9306085: {'click_count': 162, 'impression_count': 172},
#  763730: {'click_count': 2, 'impression_count': 22},
#  8645692: {'click_count': 1, 'impression_count': 31},
#  2183949: {'click_count': 81, 'impression_count': 171},
#  8266892: {'click_count': 221, 'impression_count': 231},
#  8953708: {'click_count': 4, 'impression_count': 14},
#  1431002: {'click_count': 5, 'impression_count': 25},
#  1581016: {'click_count': 9, 'impression_count': 29},
#  8682022: {'click_count': 6, 'impression_count': 26},
#  1961141: {'click_count': 6, 'impression_count': 26},
#  569921: {'click_count': 1, 'impression_count': 21},
#  6206304: {'click_count': 1, 'impression_count': 21},
#  3667719: {'click_count': 1, 'impression_count': 21},
#  8976429: {'click_count': 1, 'impression_count': 21},
#  2448719: {'click_count': 2, 'impression_count': 32},
#  1877739: {'click_count': 1, 'impression_count': 31},
#  4973298: {'click_count': 17, 'impression_count': 47},
#  9684051: {'click_count': 1, 'impression_count': 81},
#  224836: {'click_count': 3, 'impression_count': 23},
#  2009092: {'click_count': 6, 'impression_count': 56},
#  8304957: {'click_count': 2, 'impression_count': 122},
#  294733: {'click_count': 22, 'impression_count': 82},
#  8427048: {'click_count': 43, 'impression_count': 103},
#  3157269: {'click_count': 1, 'impression_count': 111},
#  5243786: {'click_count': 1, 'impression_count': 111},
#  1043713: {'click_count': 126, 'impression_count': 206},
#  1698631: {'click_count': 68, 'impression_count': 148},
#  680798: {'click_count': 42, 'impression_count': 122},
#  2079441: {'click_count': 21, 'impression_count': 101},
#  6287689: {'click_count': 11, 'impression_count': 91},
#  8581491: {'click_count': 11, 'impression_count': 91},
#  8350164: {'click_count': 40, 'impression_count': 120},
#  8742146: {'click_count': 10, 'impression_count': 90},
#  476757: {'click_count': 17, 'impression_count': 97},
#  8064507: {'click_count': 1, 'impression_count': 11},
#  3071585: {'click_count': 1, 'impression_count': 11},
#  4581991: {'click_count': 66, 'impression_count': 114},
#  3966715: {'click_count': 7, 'impression_count': 27},
#  1483268: {'click_count': 159, 'impression_count': 199},
#  5874432: {'click_count': 3, 'impression_count': 63},
#  929914: {'click_count': 3, 'impression_count': 63},
#  5490446: {'click_count': 2, 'impression_count': 62},
#  8082087: {'click_count': 1, 'impression_count': 61},
#  9767430: {'click_count': 2, 'impression_count': 62},
#  531482: {'click_count': 1, 'impression_count': 61},
#  9888185: {'click_count': 1, 'impression_count': 31},
#  5804073: {'click_count': 23, 'impression_count': 43},
#  3654688: {'click_count': 1, 'impression_count': 51},
#  5650092: {'click_count': 1, 'impression_count': 51},
#  6982024: {'click_count': 9, 'impression_count': 29},
#  7981529: {'click_count': 2, 'impression_count': 242},
#  4021478: {'click_count': 4, 'impression_count': 28},
#  3926322: {'click_count': 1, 'impression_count': 25},
#  408480: {'click_count': 119, 'impression_count': 139},
#  8555218: {'click_count': 64, 'impression_count': 84},
#  9487016: {'click_count': 6, 'impression_count': 26},
#  4804755: {'click_count': 12, 'impression_count': 92},
#  999918: {'click_count': 1, 'impression_count': 81},
#  1792572: {'click_count': 1, 'impression_count': 81},
#  8189346: {'click_count': 6, 'impression_count': 86},
#  5808465: {'click_count': 68, 'impression_count': 88},
#  37122: {'click_count': 21, 'impression_count': 81},
#  1956165: {'click_count': 1, 'impression_count': 241},
#  4154549: {'click_count': 2, 'impression_count': 32},
#  4814575: {'click_count': 5, 'impression_count': 29},
#  1363768: {'click_count': 91, 'impression_count': 141},
#  3792304: {'click_count': 1, 'impression_count': 61},
#  502613: {'click_count': 1, 'impression_count': 61},
#  6498843: {'click_count': 1, 'impression_count': 61},
#  7045284: {'click_count': 1, 'impression_count': 61},
#  6938177: {'click_count': 24, 'impression_count': 84},
#  2882290: {'click_count': 132, 'impression_count': 192},
#  509960: {'click_count': 13, 'impression_count': 73},
#  1536629: {'click_count': 1, 'impression_count': 61},
#  1538515: {'click_count': 6, 'impression_count': 56},
#  4200136: {'click_count': 7, 'impression_count': 57},
#  2217272: {'click_count': 8, 'impression_count': 58},
#  1096165: {'click_count': 8, 'impression_count': 58},
#  7303354: {'click_count': 5, 'impression_count': 55},
#  6465257: {'click_count': 4, 'impression_count': 54},
#  9493180: {'click_count': 6, 'impression_count': 56},
#  159693: {'click_count': 1, 'impression_count': 51},
#  6709203: {'click_count': 1, 'impression_count': 51},
#  8566549: {'click_count': 1, 'impression_count': 51},
#  4595679: {'click_count': 5, 'impression_count': 55},
#  4825438: {'click_count': 10, 'impression_count': 30},
#  6480195: {'click_count': 4, 'impression_count': 74},
#  2088039: {'click_count': 3, 'impression_count': 73},
#  1061144: {'click_count': 2, 'impression_count': 72},
#  1526238: {'click_count': 1, 'impression_count': 71},
#  8076654: {'click_count': 51, 'impression_count': 71},
#  9106319: {'click_count': 1, 'impression_count': 61},
#  62938: {'click_count': 1, 'impression_count': 61},
#  3614794: {'click_count': 1, 'impression_count': 61},
#  3378413: {'click_count': 107, 'impression_count': 137},
#  4747958: {'click_count': 95, 'impression_count': 125},
#  3382708: {'click_count': 157, 'impression_count': 187},
#  5306010: {'click_count': 64, 'impression_count': 94},
#  3813976: {'click_count': 32, 'impression_count': 62},
#  9728333: {'click_count': 2, 'impression_count': 42},
#  786643: {'click_count': 1, 'impression_count': 41},
#  2590455: {'click_count': 2, 'impression_count': 42},
#  6908026: {'click_count': 1, 'impression_count': 41},
#  1704863: {'click_count': 1, 'impression_count': 41},
#  444964: {'click_count': 2, 'impression_count': 22},
#  4966652: {'click_count': 99, 'impression_count': 129},
#  6967573: {'click_count': 47, 'impression_count': 77},
#  2987374: {'click_count': 17, 'impression_count': 47},
#  1261446: {'click_count': 2, 'impression_count': 102},
#  478015: {'click_count': 2, 'impression_count': 102},
#  5689593: {'click_count': 1, 'impression_count': 101},
#  6460010: {'click_count': 1, 'impression_count': 101},
#  7459832: {'click_count': 1, 'impression_count': 101},
#  1639981: {'click_count': 1, 'impression_count': 101},
#  7918407: {'click_count': 19, 'impression_count': 29},
#  1517481: {'click_count': 2, 'impression_count': 26},
#  2528707: {'click_count': 2, 'impression_count': 22},
#  1627715: {'click_count': 1, 'impression_count': 21},
#  4177646: {'click_count': 16, 'impression_count': 36},
#  2687122: {'click_count': 2, 'impression_count': 162},
#  4723175: {'click_count': 2, 'impression_count': 162},
#  3198903: {'click_count': 3, 'impression_count': 163},
#  6204523: {'click_count': 1, 'impression_count': 161},
#  1948797: {'click_count': 1, 'impression_count': 161},
#  146910: {'click_count': 1, 'impression_count': 161},
#  6133410: {'click_count': 297, 'impression_count': 321},
#  8409399: {'click_count': 27, 'impression_count': 77},
#  8105717: {'click_count': 37, 'impression_count': 87},
#  1852184: {'click_count': 16, 'impression_count': 66},
#  8948014: {'click_count': 17, 'impression_count': 67},
#  4353549: {'click_count': 11, 'impression_count': 21},
#  8379682: {'click_count': 1, 'impression_count': 131},
#  1909285: {'click_count': 1, 'impression_count': 131},
#  3863926: {'click_count': 1, 'impression_count': 131},
#  6768922: {'click_count': 89, 'impression_count': 99},
#  1629385: {'click_count': 1, 'impression_count': 21},
#  6576884: {'click_count': 12, 'impression_count': 52},
#  1782577: {'click_count': 12, 'impression_count': 72},
#  5072351: {'click_count': 6, 'impression_count': 54},
#  4711352: {'click_count': 2, 'impression_count': 50},
#  8308585: {'click_count': 3, 'impression_count': 51},
#  8444956: {'click_count': 1, 'impression_count': 49},
#  8079911: {'click_count': 1, 'impression_count': 171},
#  9344263: {'click_count': 1, 'impression_count': 171},
#  2384812: {'click_count': 1, 'impression_count': 171},
#  9994197: {'click_count': 25, 'impression_count': 45},
#  6696675: {'click_count': 2, 'impression_count': 50},
#  8139980: {'click_count': 17, 'impression_count': 77},
#  6786756: {'click_count': 6, 'impression_count': 66},
#  5982957: {'click_count': 8, 'impression_count': 68},
#  3207560: {'click_count': 2, 'impression_count': 62},
#  7858367: {'click_count': 1, 'impression_count': 61},
#  6793839: {'click_count': 1, 'impression_count': 61},
#  6243105: {'click_count': 81, 'impression_count': 131},
#  7981617: {'click_count': 47, 'impression_count': 67},
#  916716: {'click_count': 2, 'impression_count': 72},
#  1209133: {'click_count': 1, 'impression_count': 71},
#  204714: {'click_count': 1, 'impression_count': 21},
#  8890998: {'click_count': 18, 'impression_count': 38},
#  1681835: {'click_count': 206, 'impression_count': 246},
#  2199174: {'click_count': 65, 'impression_count': 105},
#  4799001: {'click_count': 43, 'impression_count': 63},
#  2612340: {'click_count': 12, 'impression_count': 32},
#  3023677: {'click_count': 1, 'impression_count': 41},
#  6112570: {'click_count': 1, 'impression_count': 41},
#  2018826: {'click_count': 50, 'impression_count': 60},
#  3613868: {'click_count': 1, 'impression_count': 91},
#  3970221: {'click_count': 1, 'impression_count': 91},
#  9706517: {'click_count': 2, 'impression_count': 92},
#  329838: {'click_count': 1, 'impression_count': 91},
#  9917570: {'click_count': 4, 'impression_count': 124},
#  2900320: {'click_count': 1, 'impression_count': 121},
#  4401553: {'click_count': 1, 'impression_count': 121},
#  6453411: {'click_count': 3, 'impression_count': 13},
#  1128881: {'click_count': 1, 'impression_count': 121},
#  6322711: {'click_count': 1, 'impression_count': 121},
#  3184329: {'click_count': 31, 'impression_count': 61},
#  8015458: {'click_count': 106, 'impression_count': 136},
#  4389309: {'click_count': 2, 'impression_count': 122},
#  3590213: {'click_count': 7, 'impression_count': 127},
#  6784406: {'click_count': 3, 'impression_count': 123},
#  8955970: {'click_count': 1, 'impression_count': 121},
#  9455246: {'click_count': 3, 'impression_count': 123},
#  9149331: {'click_count': 1, 'impression_count': 121},
#  2904529: {'click_count': 1, 'impression_count': 121},
#  7325943: {'click_count': 1, 'impression_count': 121},
#  7405133: {'click_count': 1, 'impression_count': 121},
#  9459828: {'click_count': 1, 'impression_count': 121},
#  1113958: {'click_count': 2, 'impression_count': 62},
#  1195511: {'click_count': 2, 'impression_count': 62},
#  2503076: {'click_count': 1, 'impression_count': 61},
#  1545436: {'click_count': 2, 'impression_count': 92},
#  6492854: {'click_count': 4, 'impression_count': 94},
#  8529483: {'click_count': 1, 'impression_count': 91},
#  5960421: {'click_count': 1, 'impression_count': 91},
#  9270279: {'click_count': 2, 'impression_count': 92},
#  5874015: {'click_count': 1, 'impression_count': 91},
#  8183086: {'click_count': 1, 'impression_count': 91},
#  1425173: {'click_count': 1, 'impression_count': 91},
#  2934222: {'click_count': 1, 'impression_count': 91},
#  1363527: {'click_count': 1, 'impression_count': 91},
#  8349200: {'click_count': 1, 'impression_count': 91},
#  8517934: {'click_count': 19, 'impression_count': 43},
#  9102692: {'click_count': 24, 'impression_count': 44},
#  7670496: {'click_count': 1, 'impression_count': 21},
#  6724064: {'click_count': 1, 'impression_count': 71},
#  7043311: {'click_count': 1, 'impression_count': 71},
#  6418514: {'click_count': 3, 'impression_count': 73},
#  4359538: {'click_count': 1, 'impression_count': 61},
#  3282749: {'click_count': 1, 'impression_count': 61},
#  5237002: {'click_count': 2, 'impression_count': 62},
#  7697632: {'click_count': 1, 'impression_count': 61},
#  227199: {'click_count': 1, 'impression_count': 61},
#  3211023: {'click_count': 66, 'impression_count': 76},
#  7437752: {'click_count': 64, 'impression_count': 74},
#  4435413: {'click_count': 1, 'impression_count': 91},
#  1460967: {'click_count': 1, 'impression_count': 91},
#  2334880: {'click_count': 97, 'impression_count': 121},
#  5135000: {'click_count': 1, 'impression_count': 21},
#  9958149: {'click_count': 18, 'impression_count': 48},
#  3956823: {'click_count': 2, 'impression_count': 32},
#  1650940: {'click_count': 5, 'impression_count': 35},
#  201901: {'click_count': 3, 'impression_count': 33},
#  7290779: {'click_count': 2, 'impression_count': 32},
#  6292845: {'click_count': 1, 'impression_count': 61},
#  2160159: {'click_count': 81, 'impression_count': 91},
#  6614817: {'click_count': 14, 'impression_count': 24},
#  407025: {'click_count': 17, 'impression_count': 113},
#  8655964: {'click_count': 10, 'impression_count': 106},
#  9661551: {'click_count': 11, 'impression_count': 107},
#  4536039: {'click_count': 12, 'impression_count': 108},
#  927662: {'click_count': 3, 'impression_count': 99},
#  5258910: {'click_count': 5, 'impression_count': 101},
#  5124667: {'click_count': 5, 'impression_count': 101},
#  3657460: {'click_count': 6, 'impression_count': 102},
#  1718735: {'click_count': 6, 'impression_count': 102},
#  7740997: {'click_count': 6, 'impression_count': 102},
#  3881596: {'click_count': 2, 'impression_count': 98},
#  305387: {'click_count': 4, 'impression_count': 100},
#  8798886: {'click_count': 2, 'impression_count': 98},
#  2548803: {'click_count': 4, 'impression_count': 134},
#  9902844: {'click_count': 1, 'impression_count': 131},
#  426057: {'click_count': 1, 'impression_count': 131},
#  536254: {'click_count': 5, 'impression_count': 135},
#  7600094: {'click_count': 2, 'impression_count': 132},
#  9485007: {'click_count': 8, 'impression_count': 58},
#  7206403: {'click_count': 6, 'impression_count': 56},
#  8911703: {'click_count': 2, 'impression_count': 52},
#  2533379: {'click_count': 1, 'impression_count': 51},
#  6134569: {'click_count': 1, 'impression_count': 51},
#  4484273: {'click_count': 3, 'impression_count': 83},
#  7742260: {'click_count': 1, 'impression_count': 81},
#  5589613: {'click_count': 1, 'impression_count': 81},
#  1873006: {'click_count': 1, 'impression_count': 41},
#  9748567: {'click_count': 2, 'impression_count': 42},
#  7938432: {'click_count': 1, 'impression_count': 41},
#  3925079: {'click_count': 1, 'impression_count': 73},
#  3909970: {'click_count': 1, 'impression_count': 141},
#  3032259: {'click_count': 1, 'impression_count': 141},
#  7110958: {'click_count': 1, 'impression_count': 141},
#  9968767: {'click_count': 1, 'impression_count': 141},
#  8755975: {'click_count': 1, 'impression_count': 41},
#  2703725: {'click_count': 22, 'impression_count': 52},
#  7347920: {'click_count': 3, 'impression_count': 23},
#  5971351: {'click_count': 3, 'impression_count': 75},
#  7316328: {'click_count': 1, 'impression_count': 145},
#  787140: {'click_count': 1, 'impression_count': 21},
#  7842708: {'click_count': 7, 'impression_count': 17},
#  8610177: {'click_count': 2, 'impression_count': 32},
#  9201066: {'click_count': 1, 'impression_count': 31},
#  6779683: {'click_count': 1, 'impression_count': 21},
#  8565829: {'click_count': 5, 'impression_count': 25},
#  1798536: {'click_count': 26, 'impression_count': 156},
#  1368167: {'click_count': 34, 'impression_count': 164},
#  3034673: {'click_count': 9, 'impression_count': 139},
#  3582470: {'click_count': 1, 'impression_count': 81},
#  6075933: {'click_count': 8, 'impression_count': 118},
#  5099515: {'click_count': 8, 'impression_count': 118},
#  7926357: {'click_count': 2, 'impression_count': 92},
#  9285461: {'click_count': 35, 'impression_count': 85},
#  1791930: {'click_count': 10, 'impression_count': 60},
#  9494113: {'click_count': 35, 'impression_count': 55},
#  8009893: {'click_count': 4, 'impression_count': 124},
#  5812307: {'click_count': 75, 'impression_count': 105},
#  3327471: {'click_count': 39, 'impression_count': 69},
#  182595: {'click_count': 10, 'impression_count': 30},
#  391938: {'click_count': 3, 'impression_count': 51},
#  8519663: {'click_count': 5, 'impression_count': 53},
#  6263288: {'click_count': 25, 'impression_count': 45},
#  7175439: {'click_count': 2, 'impression_count': 52},
#  5697914: {'click_count': 2, 'impression_count': 52},
#  4660968: {'click_count': 8, 'impression_count': 58},
#  3116842: {'click_count': 1, 'impression_count': 51},
#  4385405: {'click_count': 1, 'impression_count': 31},
#  2563424: {'click_count': 51, 'impression_count': 81},
#  1965452: {'click_count': 1, 'impression_count': 41},
#  6187780: {'click_count': 2, 'impression_count': 32},
#  3317837: {'click_count': 1, 'impression_count': 21},
#  8598106: {'click_count': 1, 'impression_count': 21},
#  8778357: {'click_count': 1, 'impression_count': 21},
#  5836236: {'click_count': 3, 'impression_count': 23},
#  1300103: {'click_count': 7, 'impression_count': 27},
#  2090866: {'click_count': 1, 'impression_count': 73},
#  9501479: {'click_count': 67, 'impression_count': 97},
#  366649: {'click_count': 5, 'impression_count': 25},
#  6711961: {'click_count': 1, 'impression_count': 61},
#  1313943: {'click_count': 2, 'impression_count': 62},
#  4872665: {'click_count': 1, 'impression_count': 61},
#  9849728: {'click_count': 1, 'impression_count': 61},
#  9967469: {'click_count': 1, 'impression_count': 25},
#  1562523: {'click_count': 2, 'impression_count': 26},
#  6205682: {'click_count': 4, 'impression_count': 28},
#  7941088: {'click_count': 2, 'impression_count': 26},
#  8954773: {'click_count': 1, 'impression_count': 21},
#  1920891: {'click_count': 59, 'impression_count': 159},
#  9451381: {'click_count': 12, 'impression_count': 112},
#  7762529: {'click_count': 4, 'impression_count': 104},
#  6700996: {'click_count': 100, 'impression_count': 130},
#  4733525: {'click_count': 23, 'impression_count': 43},
#  2915961: {'click_count': 1, 'impression_count': 49},
#  5997341: {'click_count': 35, 'impression_count': 65},
#  2717261: {'click_count': 20, 'impression_count': 50},
#  4028379: {'click_count': 2, 'impression_count': 52},
#  8911125: {'click_count': 1, 'impression_count': 51},
#  7072996: {'click_count': 2, 'impression_count': 52},
#  9608996: {'click_count': 99, 'impression_count': 129},
#  8188849: {'click_count': 2, 'impression_count': 152},
#  5749750: {'click_count': 1, 'impression_count': 31},
#  6076957: {'click_count': 83, 'impression_count': 103},
#  4114442: {'click_count': 4, 'impression_count': 34},
#  7539545: {'click_count': 1, 'impression_count': 21},
#  6809923: {'click_count': 24, 'impression_count': 48},
#  3093506: {'click_count': 1, 'impression_count': 21},
#  293271: {'click_count': 4, 'impression_count': 28},
#  6969138: {'click_count': 2, 'impression_count': 26},
#  1137840: {'click_count': 1, 'impression_count': 25},
#  951488: {'click_count': 1, 'impression_count': 11},
#  5197810: {'click_count': 31, 'impression_count': 141},
#  2455824: {'click_count': 21, 'impression_count': 131},
#  6926282: {'click_count': 32, 'impression_count': 142},
#  520330: {'click_count': 8, 'impression_count': 118},
#  1541352: {'click_count': 15, 'impression_count': 125},
#  5093567: {'click_count': 11, 'impression_count': 121},
#  8403026: {'click_count': 13, 'impression_count': 123},
#  3919702: {'click_count': 4, 'impression_count': 114},
#  2622248: {'click_count': 4, 'impression_count': 114},
#  1869009: {'click_count': 2, 'impression_count': 112},
#  2922037: {'click_count': 1, 'impression_count': 111},
#  8516184: {'click_count': 1, 'impression_count': 111},
#  4603763: {'click_count': 4, 'impression_count': 114},
#  1490146: {'click_count': 1, 'impression_count': 97},
#  6100372: {'click_count': 2, 'impression_count': 98},
#  63684: {'click_count': 1, 'impression_count': 97},
#  4779447: {'click_count': 11, 'impression_count': 31},
#  6835459: {'click_count': 5, 'impression_count': 25},
#  3622390: {'click_count': 13, 'impression_count': 85},
#  2320951: {'click_count': 12, 'impression_count': 84},
#  1339236: {'click_count': 2, 'impression_count': 42},
#  1486691: {'click_count': 1, 'impression_count': 41},
#  7795454: {'click_count': 2, 'impression_count': 42},
#  6794436: {'click_count': 1, 'impression_count': 41},
#  4878133: {'click_count': 1, 'impression_count': 41},
#  1062714: {'click_count': 2, 'impression_count': 42},
#  2997094: {'click_count': 125, 'impression_count': 365},
#  7561776: {'click_count': 14, 'impression_count': 254},
#  2209132: {'click_count': 23, 'impression_count': 263},
#  9298687: {'click_count': 68, 'impression_count': 308},
#  2009692: {'click_count': 36, 'impression_count': 276},
#  8613785: {'click_count': 28, 'impression_count': 268},
#  161671: {'click_count': 20, 'impression_count': 260},
#  7536139: {'click_count': 18, 'impression_count': 258},
#  4181948: {'click_count': 6, 'impression_count': 46},
#  4895018: {'click_count': 1, 'impression_count': 41},
#  3903359: {'click_count': 1, 'impression_count': 41},
#  7752983: {'click_count': 17, 'impression_count': 47},
#  7702551: {'click_count': 6, 'impression_count': 26},
#  2788192: {'click_count': 2, 'impression_count': 22},
#  8400864: {'click_count': 9, 'impression_count': 19},
#  6431553: {'click_count': 6, 'impression_count': 126},
#  8850380: {'click_count': 2, 'impression_count': 122},
#  7080713: {'click_count': 4, 'impression_count': 124},
#  2498685: {'click_count': 1, 'impression_count': 121},
#  7913757: {'click_count': 31, 'impression_count': 81},
#  9557931: {'click_count': 29, 'impression_count': 49},
#  4191009: {'click_count': 15, 'impression_count': 45},
#  1321194: {'click_count': 9, 'impression_count': 39},
#  2963620: {'click_count': 1, 'impression_count': 21},
#  5339383: {'click_count': 3, 'impression_count': 53},
#  4971845: {'click_count': 1, 'impression_count': 131},
#  5612811: {'click_count': 20, 'impression_count': 44},
#  1907729: {'click_count': 2, 'impression_count': 32},
#  8126398: {'click_count': 1, 'impression_count': 121},
#  1591124: {'click_count': 2, 'impression_count': 22},
#  4062998: {'click_count': 1, 'impression_count': 21},
#  6626952: {'click_count': 2, 'impression_count': 152},
#  4348338: {'click_count': 1, 'impression_count': 151},
#  2055865: {'click_count': 1, 'impression_count': 151},
#  1486616: {'click_count': 1, 'impression_count': 151},
#  3081913: {'click_count': 1, 'impression_count': 151},
#  771773: {'click_count': 8, 'impression_count': 56},
#  8787845: {'click_count': 1, 'impression_count': 51},
#  3598599: {'click_count': 1, 'impression_count': 51},
#  4347909: {'click_count': 2, 'impression_count': 22},
#  9937670: {'click_count': 2, 'impression_count': 22},
#  9875413: {'click_count': 1, 'impression_count': 21},
#  954744: {'click_count': 22, 'impression_count': 172},
#  7692172: {'click_count': 12, 'impression_count': 162},
#  1811813: {'click_count': 61, 'impression_count': 211},
#  625193: {'click_count': 1, 'impression_count': 151},
#  3546533: {'click_count': 1, 'impression_count': 151},
#  8661301: {'click_count': 1, 'impression_count': 151},
#  2214480: {'click_count': 1, 'impression_count': 151},
#  3087342: {'click_count': 1, 'impression_count': 151},
#  6785721: {'click_count': 3, 'impression_count': 153},
#  4341530: {'click_count': 2, 'impression_count': 22},
#  8579838: {'click_count': 43, 'impression_count': 53},
#  6970259: {'click_count': 69, 'impression_count': 79},
#  2514432: {'click_count': 53, 'impression_count': 123},
#  8950721: {'click_count': 27, 'impression_count': 97},
#  482288: {'click_count': 1, 'impression_count': 41},
#  8027892: {'click_count': 1, 'impression_count': 41},
#  5141356: {'click_count': 6, 'impression_count': 36},
#  8135170: {'click_count': 9, 'impression_count': 39},
#  7802719: {'click_count': 1, 'impression_count': 31},
#  8663035: {'click_count': 54, 'impression_count': 114},
#  6745094: {'click_count': 10, 'impression_count': 70},
#  9637238: {'click_count': 6, 'impression_count': 66},
#  9097707: {'click_count': 6, 'impression_count': 66},
#  7982996: {'click_count': 2, 'impression_count': 62},
#  2386816: {'click_count': 1, 'impression_count': 61},
#  6184965: {'click_count': 1, 'impression_count': 71},
#  750194: {'click_count': 2, 'impression_count': 42},
#  2208604: {'click_count': 72, 'impression_count': 92},
#  5460146: {'click_count': 1, 'impression_count': 11},
#  2076771: {'click_count': 2, 'impression_count': 202},
#  8502042: {'click_count': 2, 'impression_count': 202},
#  9476132: {'click_count': 1, 'impression_count': 201},
#  2334924: {'click_count': 1, 'impression_count': 201},
#  7517006: {'click_count': 1, 'impression_count': 201},
#  8751915: {'click_count': 1, 'impression_count': 201},
#  21557: {'click_count': 1, 'impression_count': 201},
#  8867267: {'click_count': 2, 'impression_count': 202},
#  4757580: {'click_count': 1, 'impression_count': 201},
#  8225786: {'click_count': 31, 'impression_count': 81},
#  3948484: {'click_count': 5, 'impression_count': 55},
#  3701920: {'click_count': 15, 'impression_count': 25},
#  4229448: {'click_count': 108, 'impression_count': 118},
#  429397: {'click_count': 29, 'impression_count': 149},
#  6910093: {'click_count': 1, 'impression_count': 121},
#  3963936: {'click_count': 2, 'impression_count': 122},
#  9408825: {'click_count': 2, 'impression_count': 22},
#  5404469: {'click_count': 1, 'impression_count': 21},
#  5774540: {'click_count': 38, 'impression_count': 68},
#  4850096: {'click_count': 43, 'impression_count': 63},
#  7734615: {'click_count': 3, 'impression_count': 13},
#  7811884: {'click_count': 2, 'impression_count': 62},
#  7765965: {'click_count': 1, 'impression_count': 61},
#  3294116: {'click_count': 4, 'impression_count': 64},
#  7466071: {'click_count': 3, 'impression_count': 43},
#  6730522: {'click_count': 1, 'impression_count': 11},
#  5582484: {'click_count': 11, 'impression_count': 59},
#  5195102: {'click_count': 26, 'impression_count': 74},
#  4366274: {'click_count': 20, 'impression_count': 40},
#  2996762: {'click_count': 35, 'impression_count': 55},
#  6468111: {'click_count': 2, 'impression_count': 122},
#  6878150: {'click_count': 2, 'impression_count': 52},
#  8572726: {'click_count': 8, 'impression_count': 88},
#  5091396: {'click_count': 2, 'impression_count': 32},
#  830192: {'click_count': 32, 'impression_count': 82},
#  9570505: {'click_count': 3, 'impression_count': 93},
#  6445895: {'click_count': 4, 'impression_count': 94},
#  891056: {'click_count': 2, 'impression_count': 92},
#  6917815: {'click_count': 2, 'impression_count': 92},
#  9257280: {'click_count': 2, 'impression_count': 92},
#  3703779: {'click_count': 1, 'impression_count': 91},
#  3124631: {'click_count': 1, 'impression_count': 91},
#  2116876: {'click_count': 2, 'impression_count': 92},
#  7421559: {'click_count': 1, 'impression_count': 91},
#  2370013: {'click_count': 3, 'impression_count': 133},
#  4058296: {'click_count': 3, 'impression_count': 83},
#  2947790: {'click_count': 1, 'impression_count': 71},
#  2721513: {'click_count': 1, 'impression_count': 71},
#  5713374: {'click_count': 1, 'impression_count': 71},
#  2211463: {'click_count': 9, 'impression_count': 89},
#  1555023: {'click_count': 141, 'impression_count': 161},
#  8656678: {'click_count': 151, 'impression_count': 171},
#  8666413: {'click_count': 1, 'impression_count': 41},
#  8187132: {'click_count': 2, 'impression_count': 42},
#  7543495: {'click_count': 1, 'impression_count': 41},
#  8654858: {'click_count': 129, 'impression_count': 149},
#  9447395: {'click_count': 1, 'impression_count': 121},
#  3045762: {'click_count': 1, 'impression_count': 121},
#  9227355: {'click_count': 1, 'impression_count': 121},
#  9214733: {'click_count': 1, 'impression_count': 121},
#  6394543: {'click_count': 2, 'impression_count': 122},
#  9995071: {'click_count': 1, 'impression_count': 121},
#  5019337: {'click_count': 1, 'impression_count': 121},
#  6769411: {'click_count': 8, 'impression_count': 32},
#  7603331: {'click_count': 63, 'impression_count': 103},
#  7782862: {'click_count': 14, 'impression_count': 254},
#  3959295: {'click_count': 16, 'impression_count': 256},
#  4906622: {'click_count': 29, 'impression_count': 269},
#  3552017: {'click_count': 6, 'impression_count': 246},
#  9250704: {'click_count': 7, 'impression_count': 247},
#  6529230: {'click_count': 4, 'impression_count': 244},
#  9278495: {'click_count': 18, 'impression_count': 258},
#  2883954: {'click_count': 2, 'impression_count': 242},
#  5382242: {'click_count': 9, 'impression_count': 249},
#  9602526: {'click_count': 1, 'impression_count': 241},
#  3879197: {'click_count': 4, 'impression_count': 244},
#  2026131: {'click_count': 1, 'impression_count': 241},
#  5563456: {'click_count': 1, 'impression_count': 241},
#  7374706: {'click_count': 13, 'impression_count': 43},
#  7549306: {'click_count': 1, 'impression_count': 41},
#  5780002: {'click_count': 7, 'impression_count': 47},
#  2739342: {'click_count': 4, 'impression_count': 44},
#  6478582: {'click_count': 4, 'impression_count': 44},
#  7824893: {'click_count': 44, 'impression_count': 64},
#  8771723: {'click_count': 1, 'impression_count': 41},
#  9561632: {'click_count': 2, 'impression_count': 42},
#  8940910: {'click_count': 1, 'impression_count': 41},
#  9620848: {'click_count': 1, 'impression_count': 41},
#  8231626: {'click_count': 3, 'impression_count': 43},
#  419654: {'click_count': 2, 'impression_count': 42},
#  943753: {'click_count': 1, 'impression_count': 41},
#  6505518: {'click_count': 8, 'impression_count': 38},
#  8587418: {'click_count': 4, 'impression_count': 34},
#  3311606: {'click_count': 8, 'impression_count': 98},
#  61733: {'click_count': 1, 'impression_count': 91},
#  3102639: {'click_count': 1, 'impression_count': 91},
#  2359310: {'click_count': 3, 'impression_count': 93},
#  5622429: {'click_count': 1, 'impression_count': 21},
#  3659016: {'click_count': 26, 'impression_count': 74},
#  9459195: {'click_count': 9, 'impression_count': 19},
#  742676: {'click_count': 2, 'impression_count': 62},
#  3160785: {'click_count': 1, 'impression_count': 61},
#  727083: {'click_count': 1, 'impression_count': 41},
#  3542354: {'click_count': 189, 'impression_count': 199},
#  9029216: {'click_count': 10, 'impression_count': 30},
#  8839637: {'click_count': 15, 'impression_count': 35},
#  4693461: {'click_count': 27, 'impression_count': 47},
#  4385261: {'click_count': 9, 'impression_count': 29},
#  3982688: {'click_count': 3, 'impression_count': 23},
#  604818: {'click_count': 4, 'impression_count': 24},
#  2612400: {'click_count': 5, 'impression_count': 25},
#  6638976: {'click_count': 9, 'impression_count': 219},
#  2305963: {'click_count': 2, 'impression_count': 212},
#  5258188: {'click_count': 1, 'impression_count': 211},
#  7671996: {'click_count': 1, 'impression_count': 211},
#  7067435: {'click_count': 1, 'impression_count': 211},
#  9014906: {'click_count': 1, 'impression_count': 211},
#  6060419: {'click_count': 1, 'impression_count': 211},
#  1950394: {'click_count': 1, 'impression_count': 211},
#  3988663: {'click_count': 1, 'impression_count': 211},
#  4918137: {'click_count': 1, 'impression_count': 211},
#  9311857: {'click_count': 2, 'impression_count': 32},
#  4729870: {'click_count': 1, 'impression_count': 31},
#  2547224: {'click_count': 4, 'impression_count': 24},
#  9737639: {'click_count': 4, 'impression_count': 24},
#  516704: {'click_count': 1, 'impression_count': 21},
#  6243811: {'click_count': 4, 'impression_count': 24},
#  3195792: {'click_count': 20, 'impression_count': 100},
#  5624011: {'click_count': 13, 'impression_count': 93},
#  2859704: {'click_count': 2, 'impression_count': 82},
#  8460292: {'click_count': 5, 'impression_count': 85},
#  5954812: {'click_count': 4, 'impression_count': 84},
#  6028371: {'click_count': 3, 'impression_count': 83},
#  6625084: {'click_count': 3, 'impression_count': 133},
#  160914: {'click_count': 1, 'impression_count': 131},
#  7561222: {'click_count': 1, 'impression_count': 131},
#  6124132: {'click_count': 1, 'impression_count': 131},
#  7010100: {'click_count': 1, 'impression_count': 131},
#  2459592: {'click_count': 110, 'impression_count': 180},
#  4122311: {'click_count': 9, 'impression_count': 79},
#  3332460: {'click_count': 1, 'impression_count': 71},
#  9901900: {'click_count': 25, 'impression_count': 95},
#  1509175: {'click_count': 15, 'impression_count': 85},
#  8476777: {'click_count': 9, 'impression_count': 79},
#  762244: {'click_count': 5, 'impression_count': 75},
#  9753126: {'click_count': 4, 'impression_count': 74},
#  2938604: {'click_count': 3, 'impression_count': 73},
#  5782098: {'click_count': 11, 'impression_count': 111},
#  5338028: {'click_count': 1, 'impression_count': 221},
#  4168772: {'click_count': 1, 'impression_count': 221},
#  4850483: {'click_count': 1, 'impression_count': 221},
#  6975150: {'click_count': 2, 'impression_count': 222},
#  977328: {'click_count': 84, 'impression_count': 104},
#  5606018: {'click_count': 1, 'impression_count': 81},
#  5007735: {'click_count': 40, 'impression_count': 120},
#  7662078: {'click_count': 13, 'impression_count': 93},
#  4570817: {'click_count': 27, 'impression_count': 107},
#  7016284: {'click_count': 12, 'impression_count': 92},
#  6402058: {'click_count': 1, 'impression_count': 61},
#  7837999: {'click_count': 3, 'impression_count': 133},
#  7221281: {'click_count': 1, 'impression_count': 131},
#  8320066: {'click_count': 1, 'impression_count': 21},
#  9632247: {'click_count': 2, 'impression_count': 32},
#  7736576: {'click_count': 1, 'impression_count': 31},
#  9365073: {'click_count': 1, 'impression_count': 31},
#  7946152: {'click_count': 10, 'impression_count': 40},
#  3766388: {'click_count': 5, 'impression_count': 35},
#  1891149: {'click_count': 3, 'impression_count': 33},
#  5811473: {'click_count': 1, 'impression_count': 11},
#  8977740: {'click_count': 9, 'impression_count': 29},
#  9521560: {'click_count': 12, 'impression_count': 42},
#  3470198: {'click_count': 5, 'impression_count': 35},
#  5195758: {'click_count': 23, 'impression_count': 53},
#  6218952: {'click_count': 51, 'impression_count': 81},
#  9961874: {'click_count': 111, 'impression_count': 141},
#  7452245: {'click_count': 1, 'impression_count': 11},
#  5023328: {'click_count': 1, 'impression_count': 31},
#  2603466: {'click_count': 3, 'impression_count': 23},
#  356189: {'click_count': 3, 'impression_count': 183},
#  2718690: {'click_count': 1, 'impression_count': 181},
#  7758729: {'click_count': 1, 'impression_count': 181},
#  8440146: {'click_count': 3, 'impression_count': 183},
#  5193561: {'click_count': 2, 'impression_count': 22},
#  6522266: {'click_count': 1, 'impression_count': 21},
#  6557176: {'click_count': 28, 'impression_count': 268},
#  749442: {'click_count': 2, 'impression_count': 12},
#  4072107: {'click_count': 1, 'impression_count': 241},
#  6900947: {'click_count': 1, 'impression_count': 241},
#  9001771: {'click_count': 2, 'impression_count': 242},
#  5052179: {'click_count': 1, 'impression_count': 61},
#  8646489: {'click_count': 3, 'impression_count': 223},
#  7566300: {'click_count': 2, 'impression_count': 222},
#  3417826: {'click_count': 1, 'impression_count': 221},
#  4110975: {'click_count': 1, 'impression_count': 221},
#  7362514: {'click_count': 53, 'impression_count': 73},
#  1148922: {'click_count': 8, 'impression_count': 28},
#  5166429: {'click_count': 5, 'impression_count': 25},
#  3101518: {'click_count': 1, 'impression_count': 221},
#  8521533: {'click_count': 1, 'impression_count': 221},
#  1884784: {'click_count': 38, 'impression_count': 78},
#  6221092: {'click_count': 2, 'impression_count': 22},
#  7654579: {'click_count': 5, 'impression_count': 35},
#  7007993: {'click_count': 4, 'impression_count': 34},
#  8386279: {'click_count': 16, 'impression_count': 66},
#  153774: {'click_count': 1, 'impression_count': 51},
#  300039: {'click_count': 1, 'impression_count': 51},
#  4817605: {'click_count': 1, 'impression_count': 231},
#  5772855: {'click_count': 1, 'impression_count': 231},
#  2092188: {'click_count': 1, 'impression_count': 231},
#  7023117: {'click_count': 1, 'impression_count': 231},
#  5711067: {'click_count': 1, 'impression_count': 231},
#  5841875: {'click_count': 1, 'impression_count': 231},
#  7441776: {'click_count': 1, 'impression_count': 231},
#  180773: {'click_count': 1, 'impression_count': 231},
#  4422671: {'click_count': 3, 'impression_count': 23},
#  2677400: {'click_count': 1, 'impression_count': 21},
#  1717676: {'click_count': 2, 'impression_count': 22},
#  2988896: {'click_count': 13, 'impression_count': 103},
#  217346: {'click_count': 8, 'impression_count': 98},
#  9440695: {'click_count': 1, 'impression_count': 51},
#  3496163: {'click_count': 1, 'impression_count': 51},
#  1089311: {'click_count': 1, 'impression_count': 31},
#  3066069: {'click_count': 5, 'impression_count': 65},
#  5371202: {'click_count': 18, 'impression_count': 32},
#  2766732: {'click_count': 1, 'impression_count': 11},
#  5079582: {'click_count': 2, 'impression_count': 72},
#  9692177: {'click_count': 16, 'impression_count': 86},
#  133537: {'click_count': 4, 'impression_count': 74},
#  6051612: {'click_count': 1, 'impression_count': 91},
#  5555606: {'click_count': 1, 'impression_count': 91},
#  6382403: {'click_count': 1, 'impression_count': 91},
#  1969940: {'click_count': 4, 'impression_count': 74},
#  8552464: {'click_count': 1, 'impression_count': 71},
#  592135: {'click_count': 1, 'impression_count': 71},
#  300800: {'click_count': 1, 'impression_count': 71},
#  9530706: {'click_count': 179, 'impression_count': 199},
#  5433177: {'click_count': 22, 'impression_count': 42},
#  8164461: {'click_count': 51, 'impression_count': 71},
#  42628: {'click_count': 1, 'impression_count': 101},
#  1100473: {'click_count': 7, 'impression_count': 47},
#  5857587: {'click_count': 1, 'impression_count': 41},
#  1898330: {'click_count': 71, 'impression_count': 119},
#  3017907: {'click_count': 78, 'impression_count': 128},
#  7020015: {'click_count': 38, 'impression_count': 88},
#  719170: {'click_count': 16, 'impression_count': 66},
#  9374691: {'click_count': 1, 'impression_count': 21},
#  8276935: {'click_count': 1, 'impression_count': 21},
#  9287782: {'click_count': 2, 'impression_count': 26},
#  7392202: {'click_count': 1, 'impression_count': 31},
#  2128787: {'click_count': 7, 'impression_count': 47},
#  6928748: {'click_count': 1, 'impression_count': 21},
#  1993721: {'click_count': 1, 'impression_count': 61},
#  8770124: {'click_count': 1, 'impression_count': 61},
#  9682816: {'click_count': 1, 'impression_count': 145},
#  2596223: {'click_count': 2, 'impression_count': 12},
#  4206568: {'click_count': 6, 'impression_count': 16},
#  7803467: {'click_count': 1, 'impression_count': 241},
#  1708738: {'click_count': 2, 'impression_count': 242},
#  1161719: {'click_count': 1, 'impression_count': 241},
#  21521: {'click_count': 1, 'impression_count': 241},
#  3818756: {'click_count': 4, 'impression_count': 14},
#  29826: {'click_count': 2, 'impression_count': 72},
#  5564919: {'click_count': 43, 'impression_count': 113},
#  2097669: {'click_count': 23, 'impression_count': 93},
#  5820296: {'click_count': 3, 'impression_count': 13},
#  811879: {'click_count': 3, 'impression_count': 13},
#  1661836: {'click_count': 2, 'impression_count': 12},
#  8912337: {'click_count': 1, 'impression_count': 11},
#  6845109: {'click_count': 3, 'impression_count': 43},
#  1498532: {'click_count': 1, 'impression_count': 91},
#  3545755: {'click_count': 59, 'impression_count': 83},
#  2454592: {'click_count': 89, 'impression_count': 129},
#  5664550: {'click_count': 2, 'impression_count': 22},
#  7381795: {'click_count': 43, 'impression_count': 73},
#  4033495: {'click_count': 5, 'impression_count': 45},
#  3224810: {'click_count': 2, 'impression_count': 32},
#  6493167: {'click_count': 2, 'impression_count': 32},
#  5298072: {'click_count': 1, 'impression_count': 31},
#  1852094: {'click_count': 2, 'impression_count': 122},
#  8774625: {'click_count': 1, 'impression_count': 21},
#  9330548: {'click_count': 1, 'impression_count': 49},
#  989389: {'click_count': 18, 'impression_count': 158},
#  1907550: {'click_count': 20, 'impression_count': 160},
#  9651260: {'click_count': 10, 'impression_count': 150},
#  3927381: {'click_count': 7, 'impression_count': 147},
#  1948378: {'click_count': 2, 'impression_count': 142},
#  6377614: {'click_count': 5, 'impression_count': 145},
#  9565367: {'click_count': 5, 'impression_count': 45},
#  301822: {'click_count': 1, 'impression_count': 41},
#  6401202: {'click_count': 55, 'impression_count': 75},
#  1444906: {'click_count': 11, 'impression_count': 31},
#  3933801: {'click_count': 3, 'impression_count': 23},
#  9703870: {'click_count': 11, 'impression_count': 31},
#  2768193: {'click_count': 45, 'impression_count': 65},
#  6900832: {'click_count': 2, 'impression_count': 26},
#  2337751: {'click_count': 1, 'impression_count': 49},
#  9641191: {'click_count': 29, 'impression_count': 39},
#  9659947: {'click_count': 2, 'impression_count': 32},
#  594902: {'click_count': 2, 'impression_count': 32},
#  9670554: {'click_count': 1, 'impression_count': 101},
#  2019296: {'click_count': 6, 'impression_count': 26},
#  5481324: {'click_count': 4, 'impression_count': 54},
#  9554598: {'click_count': 10, 'impression_count': 60},
#  3126553: {'click_count': 4, 'impression_count': 84},
#  7231177: {'click_count': 1, 'impression_count': 11},
#  509461: {'click_count': 1, 'impression_count': 51},
#  8952117: {'click_count': 4, 'impression_count': 54},
#  7800885: {'click_count': 7, 'impression_count': 31},
#  831031: {'click_count': 2, 'impression_count': 92},
#  6457547: {'click_count': 22, 'impression_count': 32},
#  9471099: {'click_count': 2, 'impression_count': 32},
#  8563833: {'click_count': 28, 'impression_count': 76},
#  76926: {'click_count': 3, 'impression_count': 103},
#  8445634: {'click_count': 9, 'impression_count': 249},
#  2170203: {'click_count': 6, 'impression_count': 246},
#  9149462: {'click_count': 4, 'impression_count': 244},
#  1299631: {'click_count': 23, 'impression_count': 33},
#  8987187: {'click_count': 44, 'impression_count': 64},
#  8855562: {'click_count': 30, 'impression_count': 50},
#  6298715: {'click_count': 14, 'impression_count': 254},
#  3421603: {'click_count': 7, 'impression_count': 247},
#  9673539: {'click_count': 2, 'impression_count': 62},
#  4257902: {'click_count': 60, 'impression_count': 80},
#  7595807: {'click_count': 30, 'impression_count': 50},
#  5057319: {'click_count': 4, 'impression_count': 54},
#  8454249: {'click_count': 1, 'impression_count': 31},
#  1856490: {'click_count': 36, 'impression_count': 146},
#  6905714: {'click_count': 2, 'impression_count': 112},
#  8344078: {'click_count': 5, 'impression_count': 115},
#  4983310: {'click_count': 2, 'impression_count': 112},
#  452049: {'click_count': 11, 'impression_count': 121},
#  6640072: {'click_count': 6, 'impression_count': 116},
#  769818: {'click_count': 1, 'impression_count': 51},
#  1356993: {'click_count': 1, 'impression_count': 51},
#  9111853: {'click_count': 1, 'impression_count': 241},
#  8614646: {'click_count': 1, 'impression_count': 217},
#  7136712: {'click_count': 2, 'impression_count': 32},
#  5377922: {'click_count': 3, 'impression_count': 33},
#  1901195: {'click_count': 1, 'impression_count': 31},
#  2868329: {'click_count': 2, 'impression_count': 32},
#  5908700: {'click_count': 2, 'impression_count': 32},
#  1536647: {'click_count': 1, 'impression_count': 31},
#  5260970: {'click_count': 1, 'impression_count': 41},
#  7726656: {'click_count': 1, 'impression_count': 41},
#  3647443: {'click_count': 2, 'impression_count': 42},
#  8663705: {'click_count': 6, 'impression_count': 16},
#  9918760: {'click_count': 7, 'impression_count': 17},
#  7803171: {'click_count': 1, 'impression_count': 91},
#  6556947: {'click_count': 55, 'impression_count': 75},
#  7525020: {'click_count': 1, 'impression_count': 21},
#  6218410: {'click_count': 4, 'impression_count': 84},
#  5153106: {'click_count': 218, 'impression_count': 268},
#  2940823: {'click_count': 49, 'impression_count': 73},
#  4669571: {'click_count': 1, 'impression_count': 25},
#  6093735: {'click_count': 1, 'impression_count': 21},
#  3567861: {'click_count': 1, 'impression_count': 21},
#  9764291: {'click_count': 136, 'impression_count': 166},
#  8222026: {'click_count': 10, 'impression_count': 60},
#  9727147: {'click_count': 2, 'impression_count': 82},
#  1147979: {'click_count': 2, 'impression_count': 82},
#  9623978: {'click_count': 1, 'impression_count': 81},
#  8109632: {'click_count': 1, 'impression_count': 81},
#  3677500: {'click_count': 2, 'impression_count': 82},
#  5212099: {'click_count': 1, 'impression_count': 81},
#  4251709: {'click_count': 96, 'impression_count': 126},
#  7772194: {'click_count': 15, 'impression_count': 55},
#  4408323: {'click_count': 1, 'impression_count': 41},
#  6982854: {'click_count': 1, 'impression_count': 41},
#  5171083: {'click_count': 1, 'impression_count': 41},
#  7824983: {'click_count': 64, 'impression_count': 74},
#  9468509: {'click_count': 1, 'impression_count': 31},
#  814754: {'click_count': 104, 'impression_count': 134},
#  4602430: {'click_count': 55, 'impression_count': 85},
#  9930914: {'click_count': 1, 'impression_count': 41},
#  8830569: {'click_count': 3, 'impression_count': 43},
#  6172489: {'click_count': 5, 'impression_count': 45},
#  6657666: {'click_count': 1, 'impression_count': 11},
#  5201159: {'click_count': 6, 'impression_count': 246},
#  5255383: {'click_count': 45, 'impression_count': 115},
#  1647654: {'click_count': 1, 'impression_count': 241},
#  3517677: {'click_count': 1, 'impression_count': 241},
#  7199066: {'click_count': 3, 'impression_count': 27},
#  4026487: {'click_count': 17, 'impression_count': 47},
#  5728431: {'click_count': 1, 'impression_count': 71},
#  4687579: {'click_count': 1, 'impression_count': 71},
#  3587504: {'click_count': 1, 'impression_count': 71},
#  1474759: {'click_count': 1, 'impression_count': 71},
#  3485093: {'click_count': 20, 'impression_count': 60},
#  2971570: {'click_count': 10, 'impression_count': 40},
#  1020487: {'click_count': 2, 'impression_count': 72},
#  9338357: {'click_count': 1, 'impression_count': 71},
#  9878307: {'click_count': 1, 'impression_count': 71},
#  4390096: {'click_count': 1, 'impression_count': 21},
#  2408418: {'click_count': 1, 'impression_count': 21},
#  5098618: {'click_count': 102, 'impression_count': 122},
#  9126277: {'click_count': 1, 'impression_count': 117},
#  1711991: {'click_count': 1, 'impression_count': 117},
#  6192695: {'click_count': 2, 'impression_count': 118},
#  3639902: {'click_count': 3, 'impression_count': 63},
#  1859054: {'click_count': 1, 'impression_count': 61},
#  5787489: {'click_count': 1, 'impression_count': 25},
#  4715131: {'click_count': 14, 'impression_count': 114},
#  2134376: {'click_count': 2, 'impression_count': 102},
#  381124: {'click_count': 3, 'impression_count': 33},
#  3043985: {'click_count': 3, 'impression_count': 33},
#  9761745: {'click_count': 2, 'impression_count': 22},
#  4449214: {'click_count': 3, 'impression_count': 53},
#  6121802: {'click_count': 1, 'impression_count': 25},
#  6861913: {'click_count': 1, 'impression_count': 131},
#  4835367: {'click_count': 1, 'impression_count': 131},
#  2870790: {'click_count': 1, 'impression_count': 131},
#  5623011: {'click_count': 1, 'impression_count': 131},
#  4969275: {'click_count': 2, 'impression_count': 132},
#  8464088: {'click_count': 1, 'impression_count': 131},
#  7680127: {'click_count': 52, 'impression_count': 132},
#  4851788: {'click_count': 5, 'impression_count': 105},
#  316796: {'click_count': 1, 'impression_count': 101},
#  4762139: {'click_count': 1, 'impression_count': 101},
#  8371458: {'click_count': 1, 'impression_count': 101},
#  1700454: {'click_count': 2, 'impression_count': 102},
#  6613375: {'click_count': 15, 'impression_count': 45},
#  1262600: {'click_count': 1, 'impression_count': 21},
#  5505200: {'click_count': 3, 'impression_count': 43},
#  9369231: {'click_count': 1, 'impression_count': 71},
#  2530149: {'click_count': 84, 'impression_count': 108},
#  8021421: {'click_count': 5, 'impression_count': 25},
#  2381687: {'click_count': 1, 'impression_count': 131},
#  8846418: {'click_count': 1, 'impression_count': 131},
#  1133396: {'click_count': 1, 'impression_count': 131},
#  2076402: {'click_count': 1, 'impression_count': 131},
#  3286720: {'click_count': 1, 'impression_count': 31},
#  2004216: {'click_count': 1, 'impression_count': 41},
#  7725850: {'click_count': 2, 'impression_count': 42},
#  4582936: {'click_count': 1, 'impression_count': 41},
#  1312129: {'click_count': 1, 'impression_count': 41},
#  6965098: {'click_count': 1, 'impression_count': 41},
#  8498760: {'click_count': 41, 'impression_count': 71},
#  4680529: {'click_count': 5, 'impression_count': 25},
#  9921344: {'click_count': 1, 'impression_count': 41},
#  2366146: {'click_count': 8, 'impression_count': 58},
#  2114878: {'click_count': 28, 'impression_count': 78},
#  1807937: {'click_count': 11, 'impression_count': 61},
#  5742630: {'click_count': 5, 'impression_count': 55},
#  1880584: {'click_count': 1, 'impression_count': 51},
#  2057230: {'click_count': 1, 'impression_count': 51},
#  9907307: {'click_count': 2, 'impression_count': 52},
#  689742: {'click_count': 1, 'impression_count': 51},
#  9569451: {'click_count': 1, 'impression_count': 51},
#  4836472: {'click_count': 2, 'impression_count': 52},
#  7470907: {'click_count': 1, 'impression_count': 51},
#  7893788: {'click_count': 1, 'impression_count': 51},
#  4152241: {'click_count': 3, 'impression_count': 43},
#  5387945: {'click_count': 1, 'impression_count': 81},
#  9378668: {'click_count': 34, 'impression_count': 54},
#  3528975: {'click_count': 1, 'impression_count': 21},
#  4085871: {'click_count': 1, 'impression_count': 41},
#  453964: {'click_count': 1, 'impression_count': 41},
#  590437: {'click_count': 2, 'impression_count': 42},
#  37378: {'click_count': 1, 'impression_count': 41},
#  6934368: {'click_count': 2, 'impression_count': 52},
#  3963938: {'click_count': 1, 'impression_count': 21},
#  9724490: {'click_count': 60, 'impression_count': 70},
#  9627039: {'click_count': 3, 'impression_count': 27},
#  1745418: {'click_count': 4, 'impression_count': 24},
#  711645: {'click_count': 14, 'impression_count': 34},
#  951916: {'click_count': 16, 'impression_count': 66},
#  6343742: {'click_count': 1, 'impression_count': 131},
#  8047808: {'click_count': 1, 'impression_count': 131},
#  6086455: {'click_count': 30, 'impression_count': 60},
#  4898445: {'click_count': 3, 'impression_count': 33},
#  9431396: {'click_count': 31, 'impression_count': 61},
#  8592702: {'click_count': 13, 'impression_count': 53},
#  905234: {'click_count': 1, 'impression_count': 71},
#  6183560: {'click_count': 1, 'impression_count': 71},
#  9852914: {'click_count': 1, 'impression_count': 71},
#  4564867: {'click_count': 2, 'impression_count': 192},
#  5982250: {'click_count': 1, 'impression_count': 191},
#  9458508: {'click_count': 1, 'impression_count': 191},
#  9520399: {'click_count': 1, 'impression_count': 21},
#  1481752: {'click_count': 5, 'impression_count': 25},
#  1526571: {'click_count': 2, 'impression_count': 32},
#  3601539: {'click_count': 7, 'impression_count': 37},
#  9637755: {'click_count': 8, 'impression_count': 38},
#  9398403: {'click_count': 5, 'impression_count': 35},
#  5954310: {'click_count': 3, 'impression_count': 23},
#  2125585: {'click_count': 7, 'impression_count': 27},
#  1628433: {'click_count': 9, 'impression_count': 29},
#  2984332: {'click_count': 3, 'impression_count': 73},
#  1531566: {'click_count': 2, 'impression_count': 72},
#  4619716: {'click_count': 3, 'impression_count': 243},
#  7622756: {'click_count': 7, 'impression_count': 17},
#  7577974: {'click_count': 8, 'impression_count': 28},
#  7895676: {'click_count': 1, 'impression_count': 31},
#  970905: {'click_count': 2, 'impression_count': 32},
#  6236570: {'click_count': 1, 'impression_count': 31},
#  7027981: {'click_count': 1, 'impression_count': 31},
#  2384788: {'click_count': 18, 'impression_count': 88},
#  ...}

# %%
agg_searches = defaultdict(
    lambda: dict(
        results=Counter(),
        clicks=Counter(),
        impressions=Counter(),
        ctr=Counter(),
    )
)

search_data = JsonFileIterator("./data/torob-search-data_v1.jsonl")
print("Aggregating searches based on raw query...")

for search in tqdm_notebook(search_data):
    print(search)
    raw_query = search["raw_query"]
    normalized_query = normalizer.normilize(raw_query)
    print(len(queries))
    if queries[normalized_query] > 50:
        results = search["result"][: np.max(search["clicked_rank"]) + 8]
        clicked_results = search["clicked_result"]
        impressions = search["impressions"]
        max_clicked = max(clicked_result.values())

        # calculate CTR and add to the counter
        for pid in clicked_results:
            ctr = (clicked_result[pid] + 1) / (impressions.get(pid, 0) + len(product_res))
            agg_searches[normalized_query]["ctr"][pid] += ctr

        # update impression counter
        agg_searches[normalized_query]["impressions"].update(impressions)

        # update result and click counter
        agg_searches[normalized_query]["results"].update(results)
        agg_searches[normalized_query]["clicks"].update(clicked_results)

# multiply clicked_normalized by CTR and update the dictionary
for query in agg_searches:
    for pid in agg_searches[query]["clicks"]:
        clicked_normalized = clicked_result[pid] / max_clicked
        ctr = agg_searches[query]["ctr"][pid]
        agg_searches[query]["clicks"][pid] *= clicked_normalized * ctr
# Out:
# Aggregating searches based on raw query...
#   0%|          | 0/2499901 [00:00<?, ?it/s]
# {'raw_query': 'لوستر سقفی برنز', 'result': [7151290, 6462477, 7385791, 8451497, None, 269453, 144158, 9839958, 2116610, 994641, 4384068, 6954861, 245867, 6283712, 3654237, 5506230, 9457219, 3775536, 1663988, 6946932, 4456008, 489939, 9930140, 9994201, 2819798, 1919015, 7121158, 1677646, 6458804, 5377684], 'clicked_result': [9457219], 'clicked_rank': [16], 'timestamp': '2022-07-24T09:21:58.752000+00:00'}
# 176427
# {'raw_query': 'قیمت هلیکوپتر', 'result': [363737, 3147253, 8720128, 9796388, 1420685, 5680879, 1268796, 7135387, 5854510, 8107623, 1349969, 2403444, 9728269, 8900752, 3316100, 2435225, 3218936, 977920, 3258142, 4887809], 'clicked_result': [3147253, 7135387], 'clicked_rank': [1, 7], 'timestamp': '2022-07-24T07:32:12.261000+00:00'}
# 176427
# {'raw_query': 'ساعت هوشمند', 'result': [2459592, 9391819, 4229448, 7824893, 1670767, 9901900, 8563833, 900897, 7611444, 7451228, 1665693, 6462973, 8258186, 4648687, 232002, 5815030, 2342213, None, 4111195, 5289550, 9083224, 7231049, 1509175, 8572726, 4943283, 2931230, 3995256, 3065636, 9023085, 8277631, 8476777, 1803417, 3870044, 2262418, 2575701, 3200289, 762244, 951916, 2404132, 8058124, 2331095, 4082413, 2884802, 4462879, 5398893, 1430844, 8543426, 9753126, 605157, 7693938, 6103490, 7056255, 31302, 2209891, 7485104, 9164678, 1363089, 3427892, 4122311, 9757980, 4752395, 6740515, 1916794, 686720, 2693593, 5288135, 3848948, 6238980, 3332778, 8752432], 'clicked_result': [900897, 2931230, 31302], 'clicked_rank': [7, 25, 52], 'timestamp': '2022-07-24T02:51:35.643000+00:00'}
# 176427
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_930098/2070654861.py in <module>
#      19         results = search["result"][: np.max(search["clicked_rank"]) + 8]
#      20         clicked_results = search["clicked_result"]
# ---> 21         impressions = search["impressions"]
#      22         max_clicked = max(clicked_result.values())
#      23
#
# KeyError: 'impressions'

# %%
test_data = JsonFileIterator("./data/test-offline-data_v1.jsonl")
with open('prediction.txt', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    for idx , row in enumerate(tqdm_notebook(test_data)):
        result_not_ranked = row["result_not_ranked"]
        result_list = []
        for res in result_not_ranked:
            item = (res ,np.ceil(clicked_result.get(res , 0)) )
            result_list.append(item)
        sorted_list = sorted(result_list, key=lambda x: x[1] , reverse=True)
        writer.writerow([x[0] for x in sorted_list])
# Out:
#   0%|          | 0/23140 [00:00<?, ?it/s]

# %%
len(product_res)
# Out:
# 511942

# %%
test_data = JsonFileIterator("./data/test-offline-data_v1.jsonl")
with open('prediction.txt', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    for idx , row in enumerate(tqdm_notebook(test_data)):
        result_not_ranked = row["result_not_ranked"]
        result_list = []
        for res in result_not_ranked:
            # item = (res ,np.ceil(clicked_result.get(res , 0)) )
            score = (clicked_result.get(res , 0) + 1 / product_res.get(res, 0) + len(product_res)) *  clicked_result.get(res , 0)
            item = (res ,score)
            result_list.append(item)
        sorted_list = sorted(result_list, key=lambda x: x[1] , reverse=True)
        writer.writerow([x[0] for x in sorted_list])
# Out:
#   0%|          | 0/23140 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_930098/2448566191.py in <module>
#       7         for res in result_not_ranked:
#       8             # item = (res ,np.ceil(clicked_result.get(res , 0)) )
# ----> 9             score = (clicked_result.get(res , 0) / product_res.get(res, 0)) *  clicked_result.get(res , 0)
#      10             item = (res ,score)
#      11             result_list.append(item)
#
# ZeroDivisionError: division by zero
