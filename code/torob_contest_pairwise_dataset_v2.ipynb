# %%
# !jupyter nbextension enable --py widgetsnbextension
from ipywidgets import FloatProgress
import pandas as pd
df = pd.DataFrame({'A': [1, 2, 3, 4], 'B': [1, 2, 3, 4]})

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df, title="Pandas Profiling Report", explorative=True)
profile.to_widgets()

import pandas as pd
from tqdm.notebook import tqdm

tqdm.pandas()

df = pd.DataFrame({"a": ["foo", "bar"], "b": ["spam", "eggs"]})
df.progress_apply(lambda row: row["a"] + row["b"], axis=1)

# %%
# !pip install datasets 
# !pip install --no-cache-dir --upgrade gdown
# !gdown 1spSFY1yieMcjGJc989bbbEheNhegmEmR
# !7z e torob-data-challenge-2023_datafiles_v1.7z
# !pip install parsivar --no-cache-dir
# !pip install hazm --no-cache-dir
# !pip install transformers 
# !pip install python-negar --no-cache-dir --upgrade
# !pip install -q sentencepiece

# %%
# !pip install datasets  --no-cache-dir
# !pip install transformers  --no-cache-dir

# %%
import json
import numpy as np
import pandas as pd

from parsivar import Normalizer
from negar.virastar import PersianEditor
import hazm

from collections import defaultdict, Counter
from tqdm.notebook import tqdm_notebook
from transformers import AutoTokenizer, AutoModel
from datasets import Dataset, DatasetDict
from collections import Counter, defaultdict
from sklearn.model_selection import train_test_split

import torch
from torch import nn
from sklearn.metrics import accuracy_score
from transformers import AdamW

# %%
class MyNormalizer:
    def __init__(self):
        self.parsivar_normalizer = Normalizer(pinglish_conversion_needed=True)
        self.hazm_normalizer = hazm.Normalizer(
            remove_extra_spaces=True,
            persian_numbers=False,
            persian_style=False,
            punctuation_spacing=False,
            remove_diacritics=True,
            affix_spacing=True,
            token_based=True,
        )

    def normilize(self, txt):
        return self.hazm_normalizer.normalize(
            self.parsivar_normalizer.normalize(txt.replace("\n", " ").lower().strip())
        )

# %%
class JsonFileIterator:
    def __init__(self, path):
        self.path = path
        self.f = open(path, "r")
        self.i = 0
        self.length = self.counter_lines()

    def __iter__(self):
        return self

    def __next__(self):
        line = self.f.readline()
        if not line:
            # End of file
            self.f.close()
            raise StopIteration
        self.i += 1
        return json.loads(line)

    def counter_lines(self):
        with open(self.path, "r") as f1:
            return sum(1 for _ in f1)

    def __len__(self):
        return self.length

# %%
normalizer = MyNormalizer()
search_data = JsonFileIterator("./data/torob-search-data_v1.jsonl")
queries = dict()
for search in tqdm_notebook(search_data):
    raw_query = search["raw_query"]
    normalized_query = normalizer.normilize(raw_query)
    if queries.get(normalized_query, -1) == -1:
        queries[normalized_query] = 1
    else:
        queries[normalized_query] += 1

# %%
len(queries)

# %%
agg_searches = defaultdict(
    lambda: dict(
        results=Counter(),
        clicks=Counter(),
    )
)

search_data = JsonFileIterator("./data/torob-search-data_v1.jsonl")
print("Aggregating searches based on raw query...")

for search in tqdm_notebook(search_data):
    raw_query = search["raw_query"]
    normalized_query = normalizer.normilize(raw_query)

    if queries[normalized_query] > 10:
        results = search["result"][: np.max(search["clicked_rank"]) + 8]
        clicked_results = search["clicked_result"]
        agg_searches[normalized_query]["results"].update(results)
        agg_searches[normalized_query]["clicks"].update(clicked_results)

# %%
len(agg_searches)

# %%
product_info = JsonFileIterator("./data/products-info_v1.jsonl")

# %%
import sqlite3

# Connect to the SQLite database
conn = sqlite3.connect("my_database.db")
c = conn.cursor()

# Create a table to store the data
c.execute(
    "CREATE TABLE products (id INTEGER PRIMARY KEY, category_name TEXT, titles TEXT, min_price REAL, max_price REAL, avg_price REAL, min_num_shops REAL, max_num_shops REAL, avg_num_shops REAL)"
)


# Insert the data into the table
for product in tqdm_notebook(product_info):
    titles_json = json.dumps(product["titles"])
    c.execute(
        "INSERT INTO products (id, category_name, titles, min_price, max_price, avg_price, min_num_shops, max_num_shops, avg_num_shops) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)",
        (
            product["id"],
            product["category_name"],
            titles_json,
            product["min_price"],
            product["max_price"],
            product["avg_price"],
            product["min_num_shops"],
            product["max_num_shops"],
            product["avg_num_shops"],
        ),
    )
# Commit the changes and close the database connection
conn.commit()
conn.close()

# %%
def find_new_words(titles_list, index_high_len):
    highest_len_title_words = titles_list[index_high_len].split()
    total_new_words = []
    for i in range(1, len(titles_list)):
        if i != index_high_len:
            words = titles_list[i].split()
            new_words = [word for word in words if word not in highest_len_title_words]
            # new_words = [word for word in new_words if word not in stop_words]
            total_new_words += new_words
    return list(set(total_new_words))

# %%
import pickle

agg_s = list(agg_searches.keys())
with open("./data/torob_list_search", "wb") as fp:
    pickle.dump(agg_s, fp)
# with open ('/content/drive/MyDrive/torob_list_search', 'rb') as fp:
# agg_s = pickle.load(fp)

# %%
conn = sqlite3.connect("my_database.db")
c = conn.cursor()
data_df = pd.DataFrame(columns=["query", "p_id", "p_des", "label"])
for query in tqdm_notebook(agg_s):
    results = agg_searches[query]
    for product_id, res_clicks in results["results"].most_common(50):
        if product_id != None:
            c.execute("SELECT * FROM products WHERE id = ?", (product_id,))
            result_product = c.fetchone()
            titles_list_product = json.loads(result_product[2])
            if len(titles_list_product) > 0:
                highest_len_product = max(titles_list_product, key=len)
                index_highest_len_product = titles_list_product.index(
                    highest_len_product
                )
                product_title_new_words = find_new_words(
                    titles_list_product, index_highest_len_product
                )
                p_des = " ".join(
                    [highest_len_product, " ".join(product_title_new_words)]
                )
                candidate_score = results["clicks"].get(product_id, 0)
                candidate_score = np.log2(candidate_score + 1)
                data_df = data_df.append(
                    {
                        "query": query,
                        "p_id": product_id,
                        "p_des": p_des,
                        "label": candidate_score,
                    },
                    ignore_index=True,
                )

# %%
data_df.to_csv("./data_trob20.csv", sep="\t", encoding="utf-8")

# %%
len(data_df)

# %%
len(data_df)

# %%
data_df.head()

# %%
conn.commit()
conn.close()

# %%
sum(data_df["label"] > 1) / len(data_df["label"])

# %%
len(agg_s)

# %%
agg_searches[agg_s[0]]

# %%
def read_json_lines(path, n_lines=None):
    """Creates a generator which reads and returns lines of
    a json lines file, one line at a time, each as a dictionary.

    This could be used as a memory-efficient alternative of `pandas.read_json`
    for reading a json lines file.
    """
    with open(path, "r") as f:
        for i, line in enumerate(f):
            if n_lines == i:
                break
            yield json.loads(line)

# %%
product = pd.DataFrame(read_json_lines("./data/products-info_v1.jsonl"))

# %%
product = product.set_index("id")

# %%
product.loc[1867826]["titles"]

# %%
data_df = pd.DataFrame(columns=["query", "p_id", "p_des", "label"])
for query in tqdm_notebook(agg_s):
    results = agg_searches[query]
    for product_id, res_clicks in results["results"].most_common(50):
        if product_id != None:
            titles_list_product = product.loc[product_id]["titles"]
            if len(titles_list_product) > 0:
                highest_len_product = max(titles_list_product, key=len)
                index_highest_len_product = titles_list_product.index(
                    highest_len_product
                )
                product_title_new_words = find_new_words(
                    titles_list_product, index_highest_len_product
                )
                p_des = " ".join(
                    [highest_len_product, " ".join(product_title_new_words)]
                )
                candidate_score = results["clicks"].get(product_id, 0)
                candidate_score = np.log2(candidate_score + 1)
                data_df = data_df.append(
                    {
                        "query": query,
                        "p_id": product_id,
                        "p_des": p_des,
                        "label": candidate_score,
                    },
                    ignore_index=True,
                )

# %% [markdown]
# product.loc[1867826]

# %%
product_info.head()

# %%
data_df.to_csv("./data_trob_without_sql.csv", sep="\t", encoding="utf-8")

# %%
data_df.head()

# %%
def read_json_lines(path, n_lines=None):
    """Creates a generator which reads and returns lines of
    a json lines file, one line at a time, each as a dictionary.

    This could be used as a memory-efficient alternative of `pandas.read_json`
    for reading a json lines file.
    """
    with open(path, "r") as f:
        for i, line in enumerate(f):
            if n_lines == i:
                break
            yield json.loads(line)

# %%
product = pd.DataFrame(read_json_lines("./data/products-info_v1.jsonl"))

# %%
product = product.set_index("id")

# %%
product.loc[1867826].min_price

# %%
agg_s[:10]

# %%
agg_searches[agg_s[0]]

# %%
def find_new_words(titles_list, index_high_len):
    highest_len_title_words = titles_list[index_high_len].split()
    total_new_words = []
    for i in range(1, len(titles_list)):
        if i != index_high_len:
            words = titles_list[i].split()
            new_words = [word for word in words if word not in highest_len_title_words]
            new_words = [word for word in new_words if word not in stopwords]
            total_new_words += new_words
    return list(set(total_new_words))

# %%
data_df = pd.DataFrame(columns=["query", "p_id", "p_des", "label"])
for query in tqdm_notebook(agg_s):

    results = agg_searches[query]
    max_num_shops = []
    for product_id, res_clicks in results["results"].most_common(60):
        if product_id != None:
            max_num_shop = product.loc[product_id].max_num_shops
            if max_num_shops != None:
                max_num_shops.append(max_num_shop)
        mean_max_shops = np.mean(max_num_shops)
    for product_id, res_clicks in results["results"].most_common(60):
        if product_id != None:
            titles_list_product = product.loc[product_id]["titles"]
            category_name = result_product[1]

            if len(titles_list_product) > 0:
                max_shops = product.loc[product_id].max_num_shops
                popularity = (
                    "popular" if (max_shops) > (mean_max_shops + 1) else "unpopular"
                )
                highest_len_product = max(titles_list_product, key=len)
                index_highest_len_product = titles_list_product.index(
                    highest_len_product
                )
                product_title_new_words = find_new_words(
                    titles_list_product, index_highest_len_product
                )

                candidate_score = results["clicks"].get(product_id, 0)
                candidate_score = np.log2(candidate_score + 1)
                clicks = results["clicks"].get(product_id, 0)
                impressions = results["results"].get(product_id, 0)
                ctr = (clicks + 1) / (impressions + len(results["results"]))
                max_clicks = np.max(list(results["clicks"].values()))
                data_df = data_df.append(
                    {
                        "query": query,
                        "category_name": category_name,
                        "p_id": product_id,
                        "new words": product_title_new_words,
                        "p_des": highest_len_product,
                        "label": candidate_score,
                        "clicks": clicks,
                        "impressions": impressions,
                        "ctr": ctr,
                        "mean_max_shops": mean_max_shops,
                        "popularity": popularity,
                        "log_normalized_candidate_score": np.log2(clicks + 1)
                        / np.log2(max_clicks),
                        "min_price": product.loc[product_id].min_price,
                    },
                    ignore_index=True,
                )

# %%
data_df
# temp_df = data_df.copy(deep=True)

# %%
# as csv
data_df.to_csv("data_df.csv", index=False)

# %%
# as Pickle
import pickle
with open('data_df.pkl', 'wb') as f:
    pickle.dump(data_df, f, pickle.HIGHEST_PROTOCOL)

# %%
clicks_j = click_data[queries[i]][products[i][j]]["clicks"]
impressions_j = click_data[queries[i]][products[i][j]]["impressions"]
ctr_j = clicks_j / impressions_j
clicks_k = click_data[queries[i]][products[i][k]]["clicks"]
impressions_k = click_data[queries[i]][products[i][k]]["impressions"]
ctr_k = clicks_k / impressions_k
rel_j = np.ceil(4 * ctr_j / max(ctr_j, ctr_k))
rel_k = np.ceil(4 * ctr_k / max(ctr_j, ctr_k))

# %%
# extract 10 queries with the highest number of products
top_10_queries = data_df.groupby("query").count().sort_values("p_id", ascending=False)[:10].index

# extract the data for the top 10 queries
top_10_queries_data = data_df[data_df["query"].isin(top_10_queries)]
# extract the data for the top 10 queries with the highest number of products
top_10_queries_highest_products = data_df.groupby("query").count().sort_values(
    "p_id", ascending=False
)[:10]
# extract the data for the top 10 queries with the highest number of products
top_10_queries_highest_products_data = data_df[
    data_df["query"].isin(top_10_queries_highest_products.index)
]

# %%
# relevance score is calculated as follows:  rel_{ctr}(q,d) = ceil(4.\frac{ctr(q,d)}{max_{d \in D_{q}} ctr(q,d)}), it's scaled to the range [0,4]
# where ctr(q,d) is the click-through rate of document d for query q, and D_{q} is the set of documents for query q.
# $ctr(q,d) = \frac{clicks(q,d)}{impressions(q,d)}$, $D_{q}$ is the set of products to be ranked for a query $q$. We sample \textbf{2} weeks of click-stream data for fine-tuning our models. We consider only those products in the result set of a query that had received at least \textbf{50} impressions to ensure reliable CTR estimates.

# add relevance score for each product
data_df["relevance"] = 0
# group by query
for query in tqdm_notebook(data_df["query"].unique()):
    # get the products for the query
    products = data_df[data_df["query"] == query]["p_id"].unique()
    # get the clicks and impressions for the products
    clicks = data_df[data_df["query"] == query]["clicks"].values
    impressions = data_df[data_df["query"] == query]["impressions"].values
    # calculate ctr
    ctr = clicks / impressions
    # calculate max ctr
    max_ctr = np.max(ctr)
    # calculate relevance score
    relevance = np.ceil(4 * ctr / max_ctr)
    # add relevance score to data_df
    data_df.loc[data_df["query"] == query, "relevance"] = relevance

# %%
# %reset -f

# %%
import numpy as np
import pandas as pd

# %%
temp_df = pd.read_csv("data_df.csv")
temp_df
# Out:
#                    query     p_id  \
# 0        لوستر سقفی برنز  6462477
# 1        لوستر سقفی برنز  7385791
# 2        لوستر سقفی برنز  3775536
# 3        لوستر سقفی برنز  1663988
# 4        لوستر سقفی برنز  6946932
# ...                  ...      ...
# 1571356  کاپشن زنانه ترک  4987530
# 1571357  کاپشن زنانه ترک  5323788
# 1571358  کاپشن زنانه ترک  6993184
# 1571359  کاپشن زنانه ترک  7938070
# 1571360  کاپشن زنانه ترک  8097039
#
#                                                      p_des  label  \
# 0               لوستر سقفی چشمه نور 5 شعله کد C2542-B برنز    2.0
# 1              لوستر سقفی چشمه نور 3 شعله کد C2542/3B برنز    0.0
# 2                 لوستر سقفی مدرن مدل نیلوفر سه تایی- سفید    0.0
# 3           لوستر سقفی کریستالی دایره سایز 25 مدل کارمانیا    0.0
# 4        لوستر سقفی کریستالی دایره سایز 25 دوبلکس مدل آداس    0.0
# ...                                                    ...    ...
# 1571356                         کاپشن زنانه ترک کد HBIN 80    0.0
# 1571357  خرید کاپشن زنانه ترک برند Koton رنگ مشکی کد ty...    0.0
# 1571358  خرید نقدی کاپشن زنانه ترک  برند TAMER COLLECTİ...    1.0
# 1571359  Kahverengi Oversize Çıt Çıt Kapamalı Kapitone ...    0.0
# 1571360                کاپشن زنانه مشکی ترکCristinaکد:۳۰۰۰    0.0
#
#                        category_name  clicks       ctr  impressions  \
# 0        کاپشن، بارانی و پالتو زنانه     3.0  0.012945         22.0
# 1        کاپشن، بارانی و پالتو زنانه     0.0  0.003236         22.0
# 2        کاپشن، بارانی و پالتو زنانه     0.0  0.003279         18.0
# 3        کاپشن، بارانی و پالتو زنانه     0.0  0.003279         18.0
# 4        کاپشن، بارانی و پالتو زنانه     0.0  0.003279         18.0
# ...                              ...     ...       ...          ...
# 1571356  کاپشن، بارانی و پالتو زنانه     0.0  0.007092          2.0
# 1571357  کاپشن، بارانی و پالتو زنانه     0.0  0.007092          2.0
# 1571358  کاپشن، بارانی و پالتو زنانه     1.0  0.014184          2.0
# 1571359  کاپشن، بارانی و پالتو زنانه     0.0  0.007092          2.0
# 1571360  کاپشن، بارانی و پالتو زنانه     0.0  0.007092          2.0
#
#          log_normalized_candidate_score  mean_max_shops  min_price  \
# 0                               1.00000        1.440678   821000.0
# 1                               0.00000        1.440678   792000.0
# 2                               0.00000        1.440678   400000.0
# 3                               0.00000        1.440678   756000.0
# 4                               0.00000        1.440678   756000.0
# ...                                 ...             ...        ...
# 1571356                         0.00000        1.000000  1602840.0
# 1571357                         0.00000        1.000000  1000000.0
# 1571358                         0.63093        1.000000  1920000.0
# 1571359                         0.00000        1.000000   840000.0
# 1571360                         0.00000        1.000000   762000.0
#
#                                                  new words popularity
# 0                                                       []  unpopular
# 1                                                    ['۳']  unpopular
# 2                                                       []  unpopular
# 3                                                       []  unpopular
# 4                                                       []  unpopular
# ...                                                    ...        ...
# 1571356                                                 []  unpopular
# 1571357      ['Dik', 'Yaka', 'Mont', 'Şişme', 'Fermuarlı']  unpopular
# 1571358  ['Vizon', 'Mont', 'Kapüşonlu', 'Beden', 'Ultra...  unpopular
# 1571359  ['ty195352872', 'رنگ', 'قهوه', 'کد', 'ترک', 'پ...  unpopular
# 1571360                                                 []  unpopular
#
# [1571361 rows x 13 columns]

# %%
# unique

# %%
# set relevance score to int and zero
# temp_df["relevance"] = 0

# %%
# rename ctr to ctr_score
temp_df.rename(columns={"ctr": "ctr_score"}, inplace=True)

# %%
# calculate ctr for each product
temp_df["ctr_score"] = temp_df["clicks"] / temp_df["impressions"]

# %%
np.unique(temp_df["ctr"].values, return_counts=True)
# Out:
# (array([4.89715965e-04, 4.98256104e-04, 5.16528926e-04, ...,
#         9.05898876e-01, 1.00787402e+00, 1.13392857e+00]),
#  array([1, 1, 1, ..., 1, 1, 1], dtype=int64))

# %%
# Out:
# array([6462477, 7385791, 3775536, ..., 6993184, 7938070, 8097039],
#       dtype=int64)

# %%
# how many products are ctr = 0
# Out:
# Empty DataFrame
# Columns: [query, p_id, p_des, label, category_name, clicks, ctr, impressions, log_normalized_candidate_score, mean_max_shops, min_price, new words, popularity]
# Index: []

# %%
ctr_zero
# Out:
# 0

# %%
# only consider products that have at least 50 impressions
temp_df = temp_df[temp_df["impressions"] >= 50]

# %%
temp_df
# Out:
#                query     p_id  \
# 59       ساعت هوشمند  9391819
# 60       ساعت هوشمند  8563833
# 61       ساعت هوشمند  2459592
# 62       ساعت هوشمند  7824893
# 63       ساعت هوشمند  9901900
# ...              ...      ...
# 1565859   buds 2 پرو  4723271
# 1565860   buds 2 پرو  6254931
# 1565861   buds 2 پرو  4760866
# 1565862   buds 2 پرو  5228927
# 1565863   buds 2 پرو  6302319
#
#                                                      p_des      label  \
# 59       ساعت هوشمند مدل T55 WATCH به همراه‌ یک عدد بند...  11.448633
# 60       ساعت هوشمند شیائومی هایلو مدل Haylou LS02 Glob...  10.246741
# 61       ساعت هوشمند شیائومی مدل Mibro Lite XPAW004 ا X...  11.157978
# 62       سیلیکون Mi Smart Band 6 - 1.56 اینچ با صفحه نم...   9.870365
# 63       ساعت هوشمند شیائومی مدل Mibro X1 – نسخه گلوبال...   9.434628
# ...                                                    ...        ...
# 1565859                           هدفون کی زد مدل ZS10 PRO   1.000000
# 1565860  هندزفری بلوتوث دوگوش شیائومی Xiaomi Redmi Buds...   1.000000
# 1565861  هندزفری بلوتوثی شیائومی Xiaomi Redmi Buds 4 Pr...   1.584963
# 1565862  هندزفری بلوتوث دوگوش شیائومی Xiaomi 1More Pist...   0.000000
# 1565863  هندزفری بلوتوث دو گوش شیائومی Xiaomi Buds 3T P...   0.000000
#
#                        category_name  clicks  ctr_score  impressions  \
# 59       کاپشن، بارانی و پالتو زنانه  2794.0   0.204657      10060.0
# 60       کاپشن، بارانی و پالتو زنانه  1214.0   0.089496       9979.0
# 61       کاپشن، بارانی و پالتو زنانه  2284.0   0.168797       9940.0
# 62       کاپشن، بارانی و پالتو زنانه   935.0   0.069144       9940.0
# 63       کاپشن، بارانی و پالتو زنانه   691.0   0.051127       9938.0
# ...                              ...     ...        ...          ...
# 1565859  کاپشن، بارانی و پالتو زنانه     1.0   0.012821         84.0
# 1565860  کاپشن، بارانی و پالتو زنانه     1.0   0.012903         83.0
# 1565861  کاپشن، بارانی و پالتو زنانه     2.0   0.019868         79.0
# 1565862  کاپشن، بارانی و پالتو زنانه     0.0   0.006667         78.0
# 1565863  کاپشن، بارانی و پالتو زنانه     0.0   0.006711         77.0
#
#          log_normalized_candidate_score  mean_max_shops  min_price  \
# 59                             1.000045       72.542373   245000.0
# 60                             0.895059       72.542373   527000.0
# 61                             0.974656       72.542373   145000.0
# 62                             0.862182       72.542373   426000.0
# 63                             0.824121       72.542373   969000.0
# ...                                 ...             ...        ...
# 1565859                        0.147180       15.694915  1700000.0
# 1565860                        0.147180       15.694915   835000.0
# 1565861                        0.233274       15.694915  2349000.0
# 1565862                        0.000000       15.694915   999000.0
# 1565863                        0.000000       15.694915  2748000.0
#
#                                                  new words popularity  \
# 59       ['watch', 'Watch', 'رنگ', 'همراه', '5', 'اپل',...  unpopular
# 60       ['سولار', 'haylou', 'مدلHaylou', 'اصل', 'کمپان...    popular
# 61       ['10', 'watch', 'رنگ', 'همراه', 'شیائومیmibro'...    popular
# 62       ['بروزکالا', '44mm', 'هوسمند', '18', 'میبند', ...    popular
# 63       ['10', 'بروزکالا', 'ATM', 'watch', 'Watch', 'ض...    popular
# ...                                                    ...        ...
# 1565859                                                 []  unpopular
# 1565860  ['18', 'Graphite', 'redmi', '(Buds', '(Glacier...    popular
# 1565861  ['پرو', 'مدل', 'ردمی', 'M2132E1', 'xiaomi', 'ه...  unpopular
# 1565862  ['Piston', 'PistoneBuds', 'PRO', 'گلوبال', 'Pi...    popular
# 1565863  ['دوتایی', 'White)', 'POR', 'hands', 'Redmi', ...  unpopular
#
#               ctr
# 59       0.277734
# 60       0.121655
# 61       0.229779
# 62       0.094064
# 63       0.069531
# ...           ...
# 1565859  0.011905
# 1565860  0.012048
# 1565861  0.025316
# 1565862  0.000000
# 1565863  0.000000
#
# [131668 rows x 14 columns]

# %%
grouped = temp_df.set_index("p_id").groupby("query")

# %%
test = temp_df.copy(deep=True)

# %%
test.set_index("p_id", inplace=True)

# %%
test
# Out:
#                    query                                              p_des  \
# p_id
# 6462477  لوستر سقفی برنز         لوستر سقفی چشمه نور 5 شعله کد C2542-B برنز
# 7385791  لوستر سقفی برنز        لوستر سقفی چشمه نور 3 شعله کد C2542/3B برنز
# 3775536  لوستر سقفی برنز           لوستر سقفی مدرن مدل نیلوفر سه تایی- سفید
# 1663988  لوستر سقفی برنز     لوستر سقفی کریستالی دایره سایز 25 مدل کارمانیا
# 6946932  لوستر سقفی برنز  لوستر سقفی کریستالی دایره سایز 25 دوبلکس مدل آداس
# ...                  ...                                                ...
# 4987530  کاپشن زنانه ترک                         کاپشن زنانه ترک کد HBIN 80
# 5323788  کاپشن زنانه ترک  خرید کاپشن زنانه ترک برند Koton رنگ مشکی کد ty...
# 6993184  کاپشن زنانه ترک  خرید نقدی کاپشن زنانه ترک  برند TAMER COLLECTİ...
# 7938070  کاپشن زنانه ترک  Kahverengi Oversize Çıt Çıt Kapamalı Kapitone ...
# 8097039  کاپشن زنانه ترک                کاپشن زنانه مشکی ترکCristinaکد:۳۰۰۰
#
#          label                category_name  clicks       ctr  impressions  \
# p_id
# 6462477    2.0  کاپشن، بارانی و پالتو زنانه     3.0  0.012945         22.0
# 7385791    0.0  کاپشن، بارانی و پالتو زنانه     0.0  0.003236         22.0
# 3775536    0.0  کاپشن، بارانی و پالتو زنانه     0.0  0.003279         18.0
# 1663988    0.0  کاپشن، بارانی و پالتو زنانه     0.0  0.003279         18.0
# 6946932    0.0  کاپشن، بارانی و پالتو زنانه     0.0  0.003279         18.0
# ...        ...                          ...     ...       ...          ...
# 4987530    0.0  کاپشن، بارانی و پالتو زنانه     0.0  0.007092          2.0
# 5323788    0.0  کاپشن، بارانی و پالتو زنانه     0.0  0.007092          2.0
# 6993184    1.0  کاپشن، بارانی و پالتو زنانه     1.0  0.014184          2.0
# 7938070    0.0  کاپشن، بارانی و پالتو زنانه     0.0  0.007092          2.0
# 8097039    0.0  کاپشن، بارانی و پالتو زنانه     0.0  0.007092          2.0
#
#          log_normalized_candidate_score  mean_max_shops  min_price  \
# p_id
# 6462477                         1.00000        1.440678   821000.0
# 7385791                         0.00000        1.440678   792000.0
# 3775536                         0.00000        1.440678   400000.0
# 1663988                         0.00000        1.440678   756000.0
# 6946932                         0.00000        1.440678   756000.0
# ...                                 ...             ...        ...
# 4987530                         0.00000        1.000000  1602840.0
# 5323788                         0.00000        1.000000  1000000.0
# 6993184                         0.63093        1.000000  1920000.0
# 7938070                         0.00000        1.000000   840000.0
# 8097039                         0.00000        1.000000   762000.0
#
#                                                  new words popularity  \
# p_id
# 6462477                                                 []  unpopular
# 7385791                                              ['۳']  unpopular
# 3775536                                                 []  unpopular
# 1663988                                                 []  unpopular
# 6946932                                                 []  unpopular
# ...                                                    ...        ...
# 4987530                                                 []  unpopular
# 5323788      ['Dik', 'Yaka', 'Mont', 'Şişme', 'Fermuarlı']  unpopular
# 6993184  ['Vizon', 'Mont', 'Kapüşonlu', 'Beden', 'Ultra...  unpopular
# 7938070  ['ty195352872', 'رنگ', 'قهوه', 'کد', 'ترک', 'پ...  unpopular
# 8097039                                                 []  unpopular
#
#          ctr_score
# p_id
# 6462477   0.136364
# 7385791   0.000000
# 3775536   0.000000
# 1663988   0.000000
# 6946932   0.000000
# ...            ...
# 4987530   0.000000
# 5323788   0.000000
# 6993184   0.500000
# 7938070   0.000000
# 8097039   0.000000
#
# [1571361 rows x 13 columns]

# %%
# max number of clicks in test df
max_clicks = np.max(test["clicks"].values)

# %%
max_clicks
# Out:
# 9220.0

# %%
grouped = test.groupby("query")

# %%
grouped.get_group("10 a")
# Out:
#         query                                              p_des     label  \
# p_id
# 7224899  10 a  گوشی موبایل شیائومی مدل REDMI 10A  دو سیم‌ کار...  6.714246
# 3243040  10 a  گوشی موبایل شیائومی مدل Redmi 10A دوسیم کارت ب...  5.321928
# 3410497  10 a  گوشی موبایل شیائومی مدل Xiaomi REDMI 10A 22023...  5.954196
# 707374   10 a  گوشی موبایل سامسونگ مدل Galaxy A32 4G دو سیم ک...  2.000000
# 6133410  10 a  گوشی موبایل سامسونگ مدل Galaxy A13 دو سیم کارت...  2.000000
# 6013462  10 a  گوشی موبایل اپل مدل iPhone 13 Pro Max Not Acti...  0.000000
# 9563634  10 a  گوشی موبایل شیائومی مدل Redmi 10A دوسیم کارت ب...  3.906891
# 6660687  10 a  گوشی موبایل سامسونگ مدل Galaxy A53 5G دو سیم ک...  1.000000
# 8560034  10 a  گوشی موبایل سامسونگ Galaxy A10S دو سیم کارت با...  1.000000
# 6076957  10 a  گوشی موبایل سامسونگ مدل Galaxy A13 دو سیم کارت...  0.000000
# 2107002  10 a  #موبایل_مینی bm10 | گوشی مینی |  موبایل انگشتی...  0.000000
# 2650689  10 a  گوشی شیائومی مدل Redmi Note 10 pro M2101K6G دو...  0.000000
# 3662019  10 a  گوشی موبایل آنر جی آر 5 یا Honor 5X با قابلیت ...  0.000000
# 5424185  10 a  گوشی موبایل سامسونگ مدل Galaxy A52s 5G SM-A528...  1.584963
# 4823781  10 a  گوشی موبایل اپل مدل iPhone 13 Pro Max  دو سیم‌...  0.000000
# 544704   10 a  گوشی موبایل شیائومی مدل Redmi 10A دوسیم کارت ب...  0.000000
# 2563424  10 a  گوشی سامسونگ Galaxy A52s (5G) دو سیم کارت ظرفی...  0.000000
# 983448   10 a  گوشی موبایل سامسونگ مدل Galaxy A52 رنگ: مشکی -...  0.000000
# 6243105  10 a  گوشی موبایل سامسونگ مدل Galaxy A73 5G دو سیم ک...  0.000000
# 6685091  10 a  گوشی موبایل سامسونگ مدل Galaxy A23 دو سیم کارت...  0.000000
# 4450428                        0.000000            87.6   4950000.0
# 8987187                        0.000000            87.6   5549000.0
# 3583373                        0.000000            87.6   3480000.0
# 9641191                        0.149244            87.6   4910000.0
# 6263288                        0.149244            87.6    330000.0
# 7981617                        0.000000            87.6   2500000.0
# 7603331                        0.000000            87.6   1950000.0
# 8855562                        0.000000            87.6   5189000.0
# 2345798                        0.149244            87.6    630000.0
# 6017339                        0.000000            87.6   4917189.0
# 4377369                        0.000000            87.6  27411000.0
# 951011                         0.000000            87.6   4439000.0
# 2733438                        0.000000            87.6    430000.0
# 8378652                        0.000000            87.6   3890000.0
#
#                                                  new words popularity
# p_id
# 7224899  ['(کارتن', '10', 'اصلی)', '3', '4GB/64GB', '10...  unpopular
# 3243040  ['220233L2G', '10', 'رم2', 'حافظه', '–', '(ارس...  unpopular
# 3410497  ['220233L2G', '10', 'اصلی)', 'و3', '–', '(ارسا...  unpopular
# 707374   ['تکرارری', 'باحافظه128گیگ', 'مدلGalaxy', 'Rom...    popular
# 6133410  ['گیگابایت,', '(کارمندی', 'Storage/4GB', 'Blue...    popular
# 6013462  ['(18', '(نات', 'iphone', '(JA', 'Alpine', 'za...    popular
# 9563634  ['220233L2G', '10', '–', 'حافظه', '(ارسال', '4...  unpopular
# 6660687  ['گیگابایت,', '256گیگابایت', '18', '8)', 'SM',...    popular
# 8560034  ['32گیگ', '32gb', 'Rom', '۳۲', '18', '۳۲گیگابا...  unpopular
# 6076957  ['گیگابایت,', '18', 'Storage/4GB', 'گیگابایت-'...    popular
# 2107002  ['10', 'چنج', '(بدون', 'طرح', 'وضعیت', 'رجیستر...  unpopular
# 2650689  ['گیگابایت,', '128GB،', 'باحافظه128گیگ', 'note...    popular
# 3662019  ['هواوی', 'ایکس', 'هوآوی', 'LTE', 'GR5', 'هانر...  unpopular
# 5424185  ['256گیگابایت', 'Rom', '8)', '(کارمندی', 'Stor...    popular
# 4823781  ['-CH', '256GB-6GB', 'White', 'Sierra', 'داخلی...    popular
# 544704   ['10', '32/3GB', '–', 'ردمی', '(ارسال', 'آ', '...  unpopular
# 2563424  ['مدلGalaxy', 'آ52', '128گیگابایت-', '18', '8)...    popular
# 983448   ['256گیگابایت', '8GB)', 'A52باحافظه256گیگ', 'R...    popular
# 6243105  ['گیگابایت,', '256گیگابایت', 'مدلBLACK', '18',...    popular
# 6685091  ['گیگابایت,', '(کارمندی', '128GB,', 'Blue,', '...    popular
# 2686300  ['گیگابایت,', '8)', '18', '128GB,', 'Blue,', '...    popular
# 1798536  ['GB)', 'Rom', '8)', 'SM', '128GB,', 'White', ...    popular
# 8498760  ['گیگابایت,', 'مدلBLACK', '18', '8)', 'SM', '1...    popular
# 2334880  ['نیازی', 'Rom', '18', 'Storage/4GB', 'Blue,',...    popular
# 5098618  ['iphone', 'باحافظه128گیگ', '(استوک)', 'GIG', ...  unpopular
# 3968010  ['(18', 'گیگابایت,', 'باحافظه128گیگ', 'Storage...    popular
# 4773645  ['iphone', 'zaa', 'Storage/4GB', '128gb', 'گیگ...  unpopular
# 8386279  ['گیگابایت,', 'باحافظه128گیگ', '18', '8)', '12...    popular
# 3017907  ['Rom', '18', 'redmi', '128GB,', 'Blue,', '۱۲۸...  unpopular
# 4251709  ['18', 'Storage/4GB', 'Nacho-4/64GB', 'SM', 'گ...  unpopular
# 4748879  ['s10سامسونگ', 'A53', 'akg-s10', 'AUX', '20', ...    popular
# 3001255  ['10', 'حافظه', '(ارسال', 'گیگ', '128GB', 'داخ...  unpopular
# 3545755  ['گیگابایت,', '18', '128/6GBMobile', 'SM', '12...    popular
# 6809923  ['white-notactive', '128GB-BLACK', '(نات', 'ip...  unpopular
# 814754   ['SM-A032', 'SM-A032F/DS', 'مدلGalaxy', 'Samsu...    popular
# 2858342  ['(18', '256گیگابایت', 'شده-', 'iphone', '(است...  unpopular
# 3015638  ['تفنگ', 'Gun', 'Airsoft', 'C10A+', '+C.10A', ...  unpopular
# 7088803  ['(18', '(نات', '256گیگابایت', 'iphone', 'zaa'...  unpopular
# 8757176  ['Rom', 'Not10pro', '(برنز)-Xiaomi', 'گیگابایت...  unpopular
# 408480   ['Rom', 'Storage/4GB', 'redmi', '(2020)', '128...  unpopular
# 9567921  ['باحافظه128گیگ', '۱۲۸/۶GB', '18', 'samsung-ga...  unpopular
# 735113   ['گیگابایت,', 'SM', 'Storage/4GB', '64/4GBMobi...    popular
# 2768193  ['گیگابایت,', '18', 'گیگابایت-', '128GB,', 'Bl...    popular
# 1107397  ['A22_5G', '(5G', 'Rom', '18', 'Storage/4GB', ...    popular
# 7020015  ['18', 'redmi', 'گیگابایت-', '128GB,', 'and', ...  unpopular
# 2717261  ['هندزفری', '256گیگابایت', 'iphone', 'Alpine',...  unpopular
# 4450428  ['SM-A226B/DC', 'A22_5G', 'Rom', '18', '5G-4/1...    popular
# 8987187  ['Rom', 'redmi', 'blue', 'گیگابایت-', 'Storage...  unpopular
# 3583373  ['Rom', 'redmi', 'گلوبال', 'داخلی', '_', 'سیم\...  unpopular
# 9641191  ['Rom', '(5G', '18', 'redmi', 'گیگابایت-', '(1...  unpopular
# 6263288  ['32گیگ', 'مدلGalaxy', 'Rom', '۳۲', '18', 'گیگ...    popular
# 7981617  ['Rom', '۳۲', '18', 'redmi', 'اصل', '(2020)', ...    popular
# 7603331  ['۱۶/1', 'Rom', 'Core-A013', 'SM', '16/32', 'S...    popular
# 8855562  ['NOTE10s', 'redmi', 'blue', 'گیگابایت-', 'اصل...  unpopular
# 2345798  ['10', 'رم1گیگابایت', 'حافظه', '–', '(ارسال', ...  unpopular
# 6017339  ['18', '128GB,', 'Storage/8GB', 'موبايل', 'and...  unpopular
# 4377369  ['(18', '(نات', '256گیگابایت', 'grapite', 'iph...  unpopular
# 951011   ['SM', 'Storage/4GB', '128GB,', '۱۲۸/۴', 'موبا...  unpopular
# 2733438  ['مدلGalaxy', 'Rom', 'SM', 'blue', 'موبايل', '...  unpopular
# 8378652  ['Storage/4GB', 'redmi', 'گیگابایت-', 'اصل', '...  unpopular

# %%
# max number of clicks in test
max_clicks = np.max(list(test["clicks"].values()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 # max number of clicks in test
# ----> 2 max_clicks = np.max(list(test["clicks"].values()))
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
test["ctr_score"] = test["clicks"] / test["impressions"]

# %%
# how many zero ctr
np.unique(test["ctr_score"].values, return_counts=True)
# Out:
# (array([0.00000000e+00, 1.22100122e-03, 1.51515152e-03, ...,
#         4.00000000e+00, 5.00000000e+00, 5.33333333e+00]),
#  array([960111,      1,      1, ...,     10,      1,      1], dtype=int64))

# %%
# get the queries with the highest number of products
queries_with_highest_number_of_products = grouped.count().sort_values(
    "p_des", ascending=False
)[:10].index

# get the data for the queries with the highest number of products
queries_with_highest_number_of_products_data = test[
    test["query"].isin(queries_with_highest_number_of_products)
]

# %%
# calculate max_ctr for each query
max_ctr = grouped.apply(lambda x: np.max(x["ctr"]))

# %%
# get min_ctr for each query
min_ctr = grouped.apply(lambda x: np.min(x["ctr"]))

# %%
min_ctr
# Out:
# query
# 0022            0.033333
# 01              0.017241
# 0180            0.022727
# 03              0.015873
# 070             0.031250
#                   ...
# یوکللی          0.007576
# یویو حرفه‌ای    0.007463
# یویو فلزی       0.011236
# یک نفره         0.004082
# یکبار مصرف      0.003448
# Length: 28624, dtype: float64

# %%
# max_ctr

# show the max_ctr sorted by value.
max_ctr.sort_values(ascending=False)
# Out:
# query
# dsp 90286                   1.133929
# هیرویت                      1.007874
# qcy t 13                    0.905899
# فلویید مای                  0.885714
# a 73 128                    0.883721
#                               ...
# ساعت مچی اتوماتیک مردانه    0.004792
# لویی ویتون                  0.004666
# ادوپرفیوم                   0.004525
# نخ و نقشه                   0.004323
# مادام کوکو                  0.004032
# Length: 28624, dtype: float64

# %%
np.unique(max_ctr.sort_values(ascending=False), return_counts=True)
# Out:
# (array([0.00403226, 0.00432277, 0.00452489, ..., 0.90589888, 1.00787402,
#         1.13392857]),
#  array([1, 1, 1, ..., 1, 1, 1], dtype=int64))

# %%
test[test["query"] == "samsung"]
# Out:
#            query                                              p_des     label  \
# p_id
# 6660687  samsung  گوشی موبایل سامسونگ مدل Galaxy A53 5G دو سیم ک...  5.321928
# 983448   samsung  گوشی موبایل سامسونگ مدل Galaxy A52 رنگ: مشکی -...  3.906891
# 6133410  samsung  گوشی موبایل سامسونگ مدل Galaxy A13 دو سیم کارت...  4.857981
# 707374   samsung  گوشی موبایل سامسونگ مدل Galaxy A32 4G دو سیم ک...  4.459432
# 4966652  samsung  گوشی موبایل سامسونگ مدل Galaxy S22 Ultra 5G دو...  4.584963
# 2334880  samsung  گوشی سامسونگ Galaxy A03s ظرفیت 64 گیگابایت رم ...  4.247928
# 6967573  samsung  گوشی موبایل سامسونگ مدل Galaxy S21 FE 5G دو سی...  3.169925
# 814754   samsung  گوشی موبایل سامسونگ مدل  Galaxy A03 Core  دو س...  3.700440
# 6076957  samsung  گوشی موبایل سامسونگ مدل Galaxy A13 دو سیم کارت...  2.807355
# 6685091  samsung  گوشی موبایل سامسونگ مدل Galaxy A23 دو سیم کارت...  3.584963
# 2686300  samsung  گوشی موبایل سامسونگ مدل Galaxy A33 5G رنگ: مشک...  3.321928
# 4251709  samsung  گوشی سامسونگ Galaxy A12 Nacho ظرفیت 64 گیگابای...  2.584963
# 8498760  samsung  گوشی موبایل سامسونگ مدل Galaxy A73 5G رنگ: خاک...  3.459432
# 5424185  samsung  گوشی موبایل سامسونگ مدل Galaxy A52s 5G SM-A528...  2.584963
# 5424185  ['256گیگابایت', 'Rom', '8)', '(کارمندی', 'Stor...    popular
# 2563424  ['مدلGalaxy', 'آ52', '128گیگابایت-', '18', '8)...    popular
# 1225804  ['s22', '(کارمندی', 'داخلی/12GB', 'موبايل', 'a...  unpopular
# 6243105  ['گیگابایت,', '256گیگابایت', 'مدلBLACK', '18',...    popular
# 3968010  ['(18', 'گیگابایت,', 'باحافظه128گیگ', 'Storage...    popular
# 1798536  ['GB)', 'Rom', '8)', 'SM', '128GB,', 'White', ...    popular
# 3545755  ['گیگابایت,', '18', '128/6GBMobile', 'SM', '12...    popular
# 4020343  ['(هند)', 'ظرفیت۱۲۸', '۱۲۸/۶GB', 'SM-M۳۲۵FV/DS...  unpopular
# 8386279  ['گیگابایت,', 'باحافظه128گیگ', '18', '8)', '12...    popular
# 1276659  ['مدلBLACK', '8)', '18', 'SM', '128گیگابایت-',...    popular
# 735113   ['گیگابایت,', 'SM', 'Storage/4GB', '64/4GBMobi...    popular
# 1884784  ['مدلGalaxy', 'Rom', 'Storage/4GB', 'موبايل', ...    popular
# 9567921  ['باحافظه128گیگ', '۱۲۸/۶GB', '18', 'samsung-ga...  unpopular
# 7603331  ['۱۶/1', 'Rom', 'Core-A013', 'SM', '16/32', 'S...    popular
# 2768193  ['گیگابایت,', '18', 'گیگابایت-', '128GB,', 'Bl...    popular
# 1107397  ['A22_5G', '(5G', 'Rom', '18', 'Storage/4GB', ...    popular
#
#               ctr
# p_id
# 6660687  0.274648
# 983448   0.098592
# 6133410  0.198582
# 707374   0.148936
# 4966652  0.164286
# 2334880  0.129496
# 6967573  0.061538
# 814754   0.096000
# 6076957  0.048387
# 6685091  0.089431
# 2686300  0.084906
# 4251709  0.048544
# 8498760  0.102041
# 5424185  0.054945
# 2563424  0.023256
# 1225804  0.025000
# 6243105  0.037975
# 3968010  0.069444
# 1798536  0.014493
# 3545755  0.014706
# 4020343  0.107692
# 8386279  0.065574
# 1276659  0.052632
# 735113   0.054545
# 1884784  0.078431
# 9567921  0.019608
# 7603331  0.060000
# 2768193  0.000000
# 1107397  0.060000

# %%
# show query data for the query "بازی فکری جنگل مخوف"
test[test["query"] == "بازی"].sort_values("ctr", ascending=False)
# Out:
#         query                                              p_des     label  \
# p_id
# 4693461  بازی  فرمان مسابقه‌ای Logitech مدل G29 سال تولید ۲۰۲...  7.988685
# 5133085  بازی       بازی جی تی ای 5 (GTA 5) فارسی مخصوص کامپیوتر  6.285402
# 8768238  بازی  کنسول بازی دستی مدل SUP 400 in 1 - ضمانت تعویض...  6.832890
# 8663035  بازی  کاکتوس سخنگو شارژی ،کاکتوس رقاص شارژی(((ارسال ...  6.108524
# 8630453  بازی  کنسول سونی مدل PlayStation Classic - ضمانت تعو...  7.219169
# 7268401  بازی   خرید بازی جی تی ای وی (GTA V) مناسب پلی استیشن 5  5.672425
# 4804755  بازی  گیره قلیان دابی برای پلی استیشن 5- GAME AND SM...  6.459432
# 3488817  بازی  کنسول بازی نینتندو سوییچ لایت رنگ فیروزه ای کن...  5.857981
# 1444906  بازی  دسته بازی سیم دار تک شوک حرفه ای PANATECH پانا...  4.169925
# 8778717  بازی  خرید بازی رد دد ریدمپشن ۲ (Red Dead Redemption...  4.087463
# 4247858  بازی  کنسول بازی نینتندو سوییچ مدل Nintendo Switch O...  4.321928
# 2648581  بازی  فرمان بازی لاجیتک Logitech G923 TRUEFORCE for ...  3.700440
# 6046855  بازی  قیمت ps5 خرید پلی استیشن 5 با درایو پی اس فایو...  5.614710
# 1270108  بازی  دسته بازی کامپیوتر حرفه ای تسکو مدل TG 115 ا T...  3.321928
# 3659016  بازی  Microsoft XBOX Series S 512GB All-Digital Cons...  5.491853
# 2340062  بازی  خرید پلی استیشن 2 نقره ای دو دسته | قیمت ps2 ن...  3.807355
# 4509473  بازی  کنسول ایکس باکس 360 نیو اسلیم جی تگ XBOX360  ه...  3.700440
# 104799   بازی  دسته بازی تسکو مدل TG 117 با گارانتی 12 ماهه ت...  2.321928
# 607262   بازی  خرید کنسول PS5 دیسک خور سری آخر 11 به همراه 2 ...  4.523562
# 9146500  بازی  بازی FIFA 22 مخصوص پلی استیشن PS4 نسخه بین الم...  2.584963
# 3073661  بازی  خرید کنسول پلی استیشن 5 دیسک خور سری آخر 11 با...  2.584963
# 9959423  بازی  کنسول بازی سونی پلی استیشن 4 مدل Slim سری CUH-...  4.807355
# 9654986  بازی  کنسول پلی استیشن 5 دیجیتال سری آخر 11 با 2 دست...  2.321928
# 4404747  بازی  کنسول بازی پلی استیشن 4 اسلیم سونی کد CUH-2016...  4.700440
# 5133265  بازی  باندل کنسول بازی سونی مدل پلی استیشن (Playstat...  2.807355
# 1739065  بازی  PlayStation 3 Slim 320GB with FIFA12 Original ...  2.000000
# 3928174  بازی  خرید بازی The Last of Us Part 2 مناسب پلی استی...  2.000000
# 7696004  بازی  کنسول مایکروسافت مدل Xbox Series X باندل Halo ...  2.000000
# 7766918  بازی  کنسول بازي XBOX Series X | آکبند | با 18 ماه گ...  4.321928
# 8606397  بازی  کنسول بازی سونی پلی استیشن 4 مدل Slim سری CUH-...  2.000000
# 397355   بازی  دسته بازی ایکس باکس وان اس و ایکس به همراه دان...  2.807355
# 2454592  بازی  پلی استیشن 4 ریجن 2 اروپا 500 گیگابایت - Plays...  3.700440
# 9703870  بازی  دسته ps2\nدسته پلی 2 اورجینال \nدسته بازی دوال...  2.807355
# 5564919  بازی  کنسول بازی سونی پلی استیشن 4 مدل Pro سری CUH-7...  4.000000
# 7404012  بازی  ایکس باکس وان اس 1 ترابایت باندل 2 دسته و بازی...  3.169925
# 2801015  بازی  Sony PlayStation 5 game console with a capacit...  3.000000
# 1350969  بازی  کنسول بازی سونی پلی استیشن 4 مدل Slim Limited ...  1.584963
# 4044178  بازی  Microsoft XBOX Series S 512GB All-Digital Cons...  3.000000
# 3978229  بازی  قیمت ps5 دیجیتال پلی استیشن 5 دیجیتال ادیشن کن...  4.087463
# 3205538  بازی  کنسول XBOX Series S باندل Fortnite + Rocket Le...  2.000000
# 5804073  بازی  کنسول بازی سونی پلی استیشن 4 مدل Slim سری CUH-...  2.321928
# 8768238  ['blue', 'Sup', 'خرید', 'black', 'Games', 'Bla...  unpopular
# 8663035  ['عروسک)', 'سفارشی', 'خارجی', 'تودی', 'کن.', '...    popular
# 8630453  ['کلاسیک', 'همراه', '5', '1', 'PS1', 'باندل', ...  unpopular
# 7268401  ['آکبند', 'GTA', 'مخصوص', 'PS5', '–', '(GTA)',...  unpopular
# 4804755  ['پایه', 'مخصوص', 'خرید', 'مدل', '0573', 'TP5'...  unpopular
# 3488817  ['10', '–', 'Zacian', ')', 'حمل', 'and', 'Gami...  unpopular
# 1444906  ['کامپیوتر', 'گيم', 'p-g502p', 'Wired', 'GAME'...  unpopular
# 8778717  ['ps4', '–', '۴', 'بوک', 'دیسک', 'dead', 'مخصو...  unpopular
# 4247858  ['With', '–', 'رنگ', 'همراه', 'حمل', 'گری', 'a...  unpopular
# 2648581  ['PS5', 'Racing', 'مسابقه\u200cای', 'Trueforec...  unpopular
# 6046855  ['خوره-', 'جامبو)', '20', 'White', 'داخلی', 'P...    popular
# 1270108  ['12', 'بروزکالا', 'سیمی', 'گیم\u200cپد', 'همر...    popular
# 3659016  ['بروزکالا', 'مجموعه', 'S-512GB', 'اضافه', 'تر...    popular
# 2340062  ['اسلیم', '۴', '–', 'SCPH-70000', 'Game', '900...  unpopular
# 4509473  ['همراه', 'HDD', '۳۶۰', 'Microsoft', 'Game', '...  unpopular
# 104799   ['بروزکالا', 'کامپیوتر', 'سیمی', 'گیم\u200cپد'...    popular
# 607262   ['مجموعه', 'اضافه', 'With', '5', 'بازي', '(111...  unpopular
# 9146500  ['ps4', '–', 'fifa', 'fifa22', 'مناسب', 'دیسک'...  unpopular
# 3073661  ['اضافه', 'همراه', '(1116', 'شارژر', 'باندل', ...  unpopular
# 9959423  ['مجموعه', 'Region2', 'ترابایت', 'Pack', 'سوني...  unpopular
# 9654986  ['مجموعه', 'اضافه', 'PS5', 'With', 'Charger', ...  unpopular
# 4404747  ['بروزکالا', 'مجموعه', 'Region2', 'سری2216', '...    popular
# 5133265  ['مجموعه', 'Drive،', 'اضافه', 'With', 'PS5', '...  unpopular
# 1739065  ['320', 'slim', 'اسلیم', 'خرید', 'حافظه', 'قیم...  unpopular
# 3928174  ['ps4', 'part', 'With', '–', 'دیسک', '(آکبند)'...  unpopular
# 7696004  ['ایکس', '–', 'ترابایت', 'الزامیست!)', '1TB', ...  unpopular
# 7766918  ['بروزکالا', 'مجموعه', 'ترابایت', '2020', '(ان...    popular
# 8606397  ['اضافه', 'مجموعه', '18', 'سوني', 'White', 'Pl...  unpopular
# 397355   ['ارتشی', 'خاکستری/آبی', 'White', 'Microsoft',...    popular
# 2454592  ['CUH-1216A', '3', '1336', 'ps4', '۴', '–', 'ح...  unpopular
# 9703870  ['blue', 'اصل', 'White', 'پلی1)', 'Playstaion'...    popular
# 5564919  ['بروزکالا', 'مجموعه', 'اضافه', 'Region2', 'سو...  unpopular
# 7404012  ['بروزکالا', 'مجموعه', '20', 'محدود', 'ترابايت...  unpopular
# 2801015  ['اضافه', 'مجموعه', 'ترابایت', '18', '(1116', ...  unpopular
# 1350969  ['اسلیم', '۴', '–', 'کد', '500GB', 'گیگ', 'بان...  unpopular
# 4044178  ['اضافه', 'مجموعه', '18', 'خرید', 'ظرفیت', '2G...  unpopular
# 3978229  ['2-825GB', 'بروزکالا', '3-825GB', 'مجموعه', '...    popular
# 3205538  ['XBox', 'Edition', 'Xbox', 'ایکس', 'خرید', 'م...  unpopular
# 5804073  ['اضافه', 'مجموعه', 'Pack', '18', 'سوني', '20'...  unpopular
# 3149457  ['ps4', '۴', '–', 'Football', 'مناسب', 'دیسک',...  unpopular
# 6185202  ['3', 'اضافه', '5', 'Controllers', 'dualsense'...  unpopular
# 398115   ['bandel', 'مجموعه', 'Joy‑Con', 'Adventure', '...  unpopular
# 3498608  ['اضافه', 'مجموعه', 'dualsense', 'Editoin)', '...  unpopular
# 2097669  ['ps4', 'مجموعه', 'With', 'کد', 'CUH-7216B', '...  unpopular
# 2141505  ['tsco', '12', 'ایکس', 'کامپیوتر', 'سیمی', '۴'...    popular
# 3933801  ['برد', 'بروزکالا', '(اورجینال)', 'اصل', 'مدلD...    popular
# 3761880  ['(robot', 'بروزکالا', 'ایکس', 'رنگ', '–', 'اس...    popular
# 6086455  ['one', '500GB', '1', 'گیگ', '[قطع', 'شد]', 'M...  unpopular
# 8402607  ['کنترلرهای', 'CFI-ZDS1', 'Controller', 'PS5',...    popular
# 688709   ['Black)', 'Night', 'رنگ', 'گیم\u200cپد', '–',...    popular
# 212627   ['tsco', 'بروزکالا', '135', 'گیم\u200cپد', 'با...    popular
# 4249955  ['اضافه', '20', 'ترابايت', 'Microsoft', 'خرید'...  unpopular
# 1190576  ['SENSE', 'بروزکالا', 'CFI-ZCT1W-فروش', 'ZCT1W...    popular
# 962119   ['FIFA21', 'ایکس', 'مجموعه', 'With', 'ترابایت'...  unpopular
# 3703353  ['one', 'طرح', 'series', 'خرید', 'Series2', 'س...  unpopular
# 6400038  ['slim', 'اسلیم', 'یکترابایت', 'Ps4', 'حافظه',...  unpopular
# 8817306  ['ارتشی', 'رنگ', 'گيم', 'sony3', '۳', 'استیشن3...  unpopular
#
#               ctr
# p_id
# 4693461  0.317839
# 5133085  0.239875
# 8768238  0.215238
# 8663035  0.205438
# 8630453  0.185930
# 7268401  0.145773
# 4804755  0.135514
# 3488817  0.131640
# 1444906  0.107595
# 8778717  0.090909
# 4247858  0.082251
# 2648581  0.082192
# 6046855  0.060226
# 1270108  0.057325
# 3659016  0.055276
# 2340062  0.052209
# 4509473  0.047431
# 104799   0.045977
# 607262   0.044355
# 9146500  0.043860
# 3073661  0.043478
# 9959423  0.035526
# 9654986  0.034483
# 4404747  0.034388
# 5133265  0.034091
# 1739065  0.032609
# 3928174  0.031915
# 7696004  0.030303
# 7766918  0.030255
# 8606397  0.028846
# 397355   0.028169
# 2454592  0.026906
# 9703870  0.025105
# 5564919  0.024917
# 7404012  0.022599
# 2801015  0.022013
# 1350969  0.021505
# 4044178  0.021407
# 3978229  0.020101
# 3205538  0.019108
# 5804073  0.017778
# 3149457  0.017544
# 6185202  0.017094
# 398115   0.016807
# 3498608  0.014523
# 2097669  0.014286
# 2141505  0.013333
# 3933801  0.013100
# 3761880  0.011407
# 6086455  0.011364
# 8402607  0.010417
# 688709   0.009434
# 212627   0.006452
# 4249955  0.006289
# 1190576  0.002825
# 962119   0.000000
# 3703353  0.000000
# 6400038  0.000000
# 8817306  0.000000

# %%
# grouped.groups
# grouped.apply(lambda x: x.columns)
# grouped.apply(lambda x: x.name)
# for first group
# grouped.apply(lambda x: x.iloc[0])
# grouped.apply(lambda x: x.iloc[0]["ctr"])

# only show first query products
for query in grouped.groups.keys():
    print(query)
    # get products for the query
    products = grouped.get_group(query).reset_index(drop=True)
    # set 
    display(grouped.get_group(query).sort_values("ctr", ascending=False))
    break
# Out:
# 10 a
#         query                                              p_des     label  \
# p_id
# 7224899  10 a  گوشی موبایل شیائومی مدل REDMI 10A  دو سیم‌ کار...  6.714246
# 3410497  10 a  گوشی موبایل شیائومی مدل Xiaomi REDMI 10A 22023...  5.954196
# 3243040  10 a  گوشی موبایل شیائومی مدل Redmi 10A دوسیم کارت ب...  5.321928
# 9563634  10 a  گوشی موبایل شیائومی مدل Redmi 10A دوسیم کارت ب...  3.906891
# 707374   10 a  گوشی موبایل سامسونگ مدل Galaxy A32 4G دو سیم ک...  2.000000
# 6133410  10 a  گوشی موبایل سامسونگ مدل Galaxy A13 دو سیم کارت...  2.000000
# 8560034  10 a  گوشی موبایل سامسونگ Galaxy A10S دو سیم کارت با...  1.000000
# 6660687  10 a  گوشی موبایل سامسونگ مدل Galaxy A53 5G دو سیم ک...  1.000000
# 6013462  10 a  گوشی موبایل اپل مدل iPhone 13 Pro Max Not Acti...  0.000000
# 6076957  10 a  گوشی موبایل سامسونگ مدل Galaxy A13 دو سیم کارت...  0.000000
# 2107002  10 a  #موبایل_مینی bm10 | گوشی مینی |  موبایل انگشتی...  0.000000
# 2650689  10 a  گوشی شیائومی مدل Redmi Note 10 pro M2101K6G دو...  0.000000
#
#                        category_name  clicks  ctr_score  impressions  \
# p_id
# 7224899  کاپشن، بارانی و پالتو زنانه   104.0   0.319149        178.0
# 3410497  کاپشن، بارانی و پالتو زنانه    61.0   0.188450        178.0
# 3243040  کاپشن، بارانی و پالتو زنانه    39.0   0.121581        178.0
# 9563634  کاپشن، بارانی و پالتو زنانه    14.0   0.045872        176.0
# 707374   کاپشن، بارانی و پالتو زنانه     3.0   0.012158        178.0
# 6133410  کاپشن، بارانی و پالتو زنانه     3.0   0.012158        178.0
# 8560034  کاپشن، بارانی و پالتو زنانه     1.0   0.007273        124.0
# 6660687  کاپشن، بارانی و پالتو زنانه     1.0   0.006250        169.0
# 6013462  کاپشن، بارانی و پالتو زنانه     0.0   0.003049        177.0
# 6076957  کاپشن، بارانی و پالتو زنانه     0.0   0.004310         81.0
# 2107002  کاپشن، بارانی و پالتو زنانه     0.0   0.004425         75.0
# 2650689  کاپشن، بارانی و پالتو زنانه     0.0   0.004717         61.0
#
#          log_normalized_candidate_score  mean_max_shops  min_price  \
# p_id
# 7224899                        1.002060            87.6    12000.0
# 3410497                        0.888628            87.6    12000.0
# 3243040                        0.794265            87.6  3039000.0
# 9563634                        0.583080            87.6  3970000.0
# 707374                         0.298488            87.6   620000.0
# 6133410                        0.298488            87.6   434000.0
# 8560034                        0.149244            87.6  2000000.0
# 6660687                        0.149244            87.6  1146249.0
# 6013462                        0.000000            87.6  5430000.0
# 6076957                        0.000000            87.6     2000.0
# 2107002                        0.000000            87.6   269999.0
# 2650689                        0.000000            87.6  6288000.0
#
#                                                  new words popularity  \
# p_id
# 7224899  ['(کارتن', '10', 'اصلی)', '3', '4GB/64GB', '10...  unpopular
#
# temp_df["relevance"] = grouped.apply(lambda x: np.ceil(4 * x["ctr"] / max_ctr[x.name]))

# %%
relevance_scores = grouped.apply(lambda x: np.ceil(4 * x["ctr"] / np.max(x["ctr"])))

# %%
print(relevance_scores[:10])
# Out:
# query  p_id
# 10 a   7224899    4.0
#        3243040    2.0
#        3410497    3.0
#        707374     1.0
#        6133410    1.0
#        6013462    0.0
#        9563634    1.0
#        6660687    1.0
#        8560034    1.0
#        6076957    0.0
# Name: ctr, dtype: float64

# %%
# show unique relevance_scores.values
np.unique(relevance_scores.values, return_counts=True)
# Out:
# (array([ 0.,  1.,  2.,  3.,  4., nan]),
#  array([ 7262, 67752, 34174, 11619, 10855,     6], dtype=int64))

# %%
# get queries with relevance score "nan"
np.unique(relevance_scores[relevance_scores.isna()].index)
# Out:
# array([('الفا اسلیم', 3680077), ('ساعت نقره زنانه', 7502006),
#        ('شیشه جلو 405', 1661566), ('شیشه جلو 405', 7524700),
#        ('موتور ساعت دیواری', 4978917), ('موتور ساعت دیواری', 9047486)],
#       dtype=object)

# %%
relevance_nan = relevance_scores[relevance_scores.isna()].index
for query in relevance_nan:
    print(query[0], query[1])
# Out:
# الفا اسلیم 3680077
# ساعت نقره زنانه 7502006
# شیشه جلو 405 7524700
# شیشه جلو 405 1661566
# موتور ساعت دیواری 9047486
# موتور ساعت دیواری 4978917

# %%
# get relevance_y values from merged_df
relevance_y = relevance_scores[relevance_scores.isna()].values
# relevance_y = relevance_scores[relevance_scores.notna()].values

# %%
np.unique(relevance_y, return_counts=True)
# Out:
# (array([nan]), array([6], dtype=int64))

# %%
# where index equals to 3680077
test[test["query"] == "الفا اسلیم"]
# Out:
#               query                                              p_des  label  \
# p_id
# 3680077  الفا اسلیم  کاور لپ تاپ WiWU مدل Alpha Slim مناسب برای لپ ...    0.0
#
#                        category_name  clicks  ctr_score  impressions  \
# p_id
# 3680077  کاپشن، بارانی و پالتو زنانه     0.0   0.013514         51.0
#
#          log_normalized_candidate_score  mean_max_shops  min_price  \
# p_id
# 3680077                             0.0       20.363636   750000.0
#
#                                                  new words popularity  ctr
# p_id
# 3680077  ['slim', 'کیف', 'اسلیم', 'آلفا', '14', 'wiwu',...  unpopular  0.0

# %%
relevance_scores.index
# Out:
# MultiIndex([(    '10 a', 7224899),
#             (    '10 a', 3243040),
#             (    '10 a', 3410497),
#             (    '10 a',  707374),
#             (    '10 a', 6133410),
#             (    '10 a', 6013462),
#             (    '10 a', 9563634),
#             (    '10 a', 6660687),
#             (    '10 a', 8560034),
#             (    '10 a', 6076957),
#             ...
#             ('یقه اسکی', 3326161),
#             ('یقه اسکی', 8753282),
#             ( 'یونولیت', 6203654),
#             ( 'یونولیت', 3468815),
#             ('یونیکورن', 9486172),
#             ('یونیکورن', 4360475),
#             ('یونیکورن', 4311994),
#             ('یونیکورن', 8758736),
#             ('یونیکورن',  905923),
#             ('یونیکورن', 2514432)],
#            names=['query', 'p_id'], length=131668)

# %%
relevance_df = pd.DataFrame(index=relevance_scores.index, columns=["relevance"], data=relevance_scores.values)

# %%
relevance_df
# Out:
#                   relevance
# query    p_id
# 10 a     7224899        4.0
#          3243040        2.0
#          3410497        3.0
#          707374         1.0
#          6133410        1.0
# ...                     ...
# یونیکورن 4360475        2.0
#          4311994        1.0
#          8758736        4.0
#          905923         1.0
#          2514432        3.0
#
# [131668 rows x 1 columns]

# %%
relevance_df.to_csv("relevance_df.csv")

# %%
relevance_df = pd.read_csv("relevance_df.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 relevance_df = pd.read_csv("relevance_df.csv")
#
# NameError: name 'pd' is not defined

# %%
relevance_df.reset_index(inplace=True)

# %%
relevance_df.drop(columns=["index"], inplace=True)

# %%
relevance_df.set_index("p_id", inplace=True)

# %%
relevance_df
# Out:
#             query  relevance
# p_id
# 7224899      10 a        4.0
# 3243040      10 a        2.0
# 3410497      10 a        3.0
# 707374       10 a        1.0
# 6133410      10 a        1.0
# ...           ...        ...
# 4360475  یونیکورن        2.0
# 4311994  یونیکورن        1.0
# 8758736  یونیکورن        4.0
# 905923   یونیکورن        1.0
# 2514432  یونیکورن        3.0
#
# [131668 rows x 2 columns]

# %%
print(relevance_df["relevance"].dtype)
print(np.unique(relevance_df["relevance"].values, return_counts=True))
# Out:
# float64
# (array([ 0.,  1.,  2.,  3.,  4., nan]), array([ 7262, 67752, 34174, 11619, 10855,     6], dtype=int64))

# %%
# replace nan values with 0
relevance_df["relevance"] = relevance_df["relevance"].fillna(0)

# %%
relevance_df["relevance"] = relevance_df["relevance"].astype("int64")

# %%
relevance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 131668 entries, 7224899 to 2514432
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   query      131668 non-null  object
#  1   relevance  131668 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 3.0+ MB

# %%
t_df = test.copy()

# t_df = t_df.set_index(["query", "p_id"])
# relevance_df.reset_index(inplace=True)

# %%
t_df["relevance"] = 0

# %%
relevance_df
# Out:
#             query  relevance
# p_id
# 7224899      10 a          4
# 3243040      10 a          2
# 3410497      10 a          3
# 707374       10 a          1
# 6133410      10 a          1
# ...           ...        ...
# 4360475  یونیکورن          2
# 4311994  یونیکورن          1
# 8758736  یونیکورن          4
# 905923   یونیکورن          1
# 2514432  یونیکورن          3
#
# [131668 rows x 2 columns]

# %%
len(t_df)
# Out:
# 131668

# %%
t_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 131668 entries, 9391819 to 6302319
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   query                           131668 non-null  object
#  1   p_des                           131668 non-null  object
#  2   label                           131668 non-null  float64
#  3   category_name                   131668 non-null  object
#  4   clicks                          131668 non-null  float64
#  5   ctr_score                       131668 non-null  float64
#  6   impressions                     131668 non-null  float64
#  7   log_normalized_candidate_score  131668 non-null  float64
#  8   mean_max_shops                  131668 non-null  float64
#  9   min_price                       130651 non-null  float64
#  10  new words                       131668 non-null  object
#  11  popularity                      131668 non-null  object
#  12  ctr                             131668 non-null  float64
#  13  relevance                       131668 non-null  int64
# dtypes: float64(8), int64(1), object(5)
# memory usage: 19.1+ MB

# %%
relevance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 131668 entries, 7224899 to 2514432
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   query      131668 non-null  object
#  1   relevance  131668 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 7.0+ MB

# %%
relevance_df
# Out:
#             query  relevance
# p_id
# 7224899      10 a          4
# 3243040      10 a          2
# 3410497      10 a          3
# 707374       10 a          1
# 6133410      10 a          1
# ...           ...        ...
# 4360475  یونیکورن          2
# 4311994  یونیکورن          1
# 8758736  یونیکورن          4
# 905923   یونیکورن          1
# 2514432  یونیکورن          3
#
# [131668 rows x 2 columns]

# %%
# add relevance score to t_df
t_df.loc[relevance_df.index, "relevance"] = relevance_df["relevance"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # add relevance score to t_df
# ----> 2 t_df.loc[relevance_df.index, "relevance"] = relevance_df["relevance"]
#
# NameError: name 'relevance_df' is not defined

# %%
t_df
# Out:
#                query                                              p_des  \
# p_id
# 9391819  ساعت هوشمند  ساعت هوشمند مدل T55 WATCH به همراه‌ یک عدد بند...
# 8563833  ساعت هوشمند  ساعت هوشمند شیائومی هایلو مدل Haylou LS02 Glob...
# 2459592  ساعت هوشمند  ساعت هوشمند شیائومی مدل Mibro Lite XPAW004 ا X...
# 7824893  ساعت هوشمند  سیلیکون Mi Smart Band 6 - 1.56 اینچ با صفحه نم...
# 9901900  ساعت هوشمند  ساعت هوشمند شیائومی مدل Mibro X1 – نسخه گلوبال...
# ...              ...                                                ...
# 4723271   buds 2 پرو                           هدفون کی زد مدل ZS10 PRO
# 6254931   buds 2 پرو  هندزفری بلوتوث دوگوش شیائومی Xiaomi Redmi Buds...
# 4760866   buds 2 پرو  هندزفری بلوتوثی شیائومی Xiaomi Redmi Buds 4 Pr...
# 5228927   buds 2 پرو  هندزفری بلوتوث دوگوش شیائومی Xiaomi 1More Pist...
# 6302319   buds 2 پرو  هندزفری بلوتوث دو گوش شیائومی Xiaomi Buds 3T P...
#
#              label                category_name  clicks  ctr_score  \
# p_id
# 9391819  11.448633  کاپشن، بارانی و پالتو زنانه  2794.0   0.204657
# 8563833  10.246741  کاپشن، بارانی و پالتو زنانه  1214.0   0.089496
# 2459592  11.157978  کاپشن، بارانی و پالتو زنانه  2284.0   0.168797
# 7824893   9.870365  کاپشن، بارانی و پالتو زنانه   935.0   0.069144
# 9901900   9.434628  کاپشن، بارانی و پالتو زنانه   691.0   0.051127
# ...            ...                          ...     ...        ...
# 4723271   1.000000  کاپشن، بارانی و پالتو زنانه     1.0   0.012821
# 6254931   1.000000  کاپشن، بارانی و پالتو زنانه     1.0   0.012903
# 4760866   1.584963  کاپشن، بارانی و پالتو زنانه     2.0   0.019868
# 5228927   0.000000  کاپشن، بارانی و پالتو زنانه     0.0   0.006667
# 6302319   0.000000  کاپشن، بارانی و پالتو زنانه     0.0   0.006711
#
#          impressions  log_normalized_candidate_score  mean_max_shops  \
# p_id
# 9391819      10060.0                        1.000045       72.542373
# 8563833       9979.0                        0.895059       72.542373
# 2459592       9940.0                        0.974656       72.542373
# 7824893       9940.0                        0.862182       72.542373
# 9901900       9938.0                        0.824121       72.542373
# ...              ...                             ...             ...
# 4723271         84.0                        0.147180       15.694915
# 6254931         83.0                        0.147180       15.694915
# 4760866         79.0                        0.233274       15.694915
# 5228927         78.0                        0.000000       15.694915
# 6302319         77.0                        0.000000       15.694915
#
#          min_price                                          new words  \
# p_id
# 9391819   245000.0  ['watch', 'Watch', 'رنگ', 'همراه', '5', 'اپل',...
# 8563833   527000.0  ['سولار', 'haylou', 'مدلHaylou', 'اصل', 'کمپان...
# 2459592   145000.0  ['10', 'watch', 'رنگ', 'همراه', 'شیائومیmibro'...
# 7824893   426000.0  ['بروزکالا', '44mm', 'هوسمند', '18', 'میبند', ...
# 9901900   969000.0  ['10', 'بروزکالا', 'ATM', 'watch', 'Watch', 'ض...
# ...            ...                                                ...
# 4723271  1700000.0                                                 []
# 6254931   835000.0  ['18', 'Graphite', 'redmi', '(Buds', '(Glacier...
# 4760866  2349000.0  ['پرو', 'مدل', 'ردمی', 'M2132E1', 'xiaomi', 'ه...
# 5228927   999000.0  ['Piston', 'PistoneBuds', 'PRO', 'گلوبال', 'Pi...
# 6302319  2748000.0  ['دوتایی', 'White)', 'POR', 'hands', 'Redmi', ...
#
#         popularity       ctr  relevance
# p_id
# 9391819  unpopular  0.277734          0
# 8563833    popular  0.121655          0
# 2459592    popular  0.229779          0
# 7824893    popular  0.094064          0
# 9901900    popular  0.069531          0
# ...            ...       ...        ...
# 4723271  unpopular  0.011905          0
# 6254931    popular  0.012048          0
# 4760866  unpopular  0.025316          0
# 5228927    popular  0.000000          0
# 6302319  unpopular  0.000000          0
#
# [131668 rows x 14 columns]

# %%
np.unique(t_df["relevance"], return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4], dtype=int64),
#  array([ 42499, 476639, 157372,  56885,  85199], dtype=int64))

# %%
relevance_df
# Out:
#             query  relevance
# p_id
# 7224899      10 a          4
# 3243040      10 a          2
# 3410497      10 a          3
# 707374       10 a          1
# 6133410      10 a          1
# ...           ...        ...
# 4360475  یونیکورن          2
# 4311994  یونیکورن          1
# 8758736  یونیکورن          4
# 905923   یونیکورن          1
# 2514432  یونیکورن          3
#
# [131668 rows x 2 columns]

# %%
# where query_x equals to "10 a" and index is 7224899
t_df[(t_df["query_x"] == "10 a") & (t_df.index == 7224899)]
# Out:
#         query_x                                              p_des     label  \
# p_id
# 7224899    10 a  گوشی موبایل شیائومی مدل REDMI 10A  دو سیم‌ کار...  6.714246
# 7224899    10 a  گوشی موبایل شیائومی مدل REDMI 10A  دو سیم‌ کار...  6.714246
# 7224899    10 a  گوشی موبایل شیائومی مدل REDMI 10A  دو سیم‌ کار...  6.714246
# 7224899    10 a  گوشی موبایل شیائومی مدل REDMI 10A  دو سیم‌ کار...  6.714246
# 7224899    10 a  گوشی موبایل شیائومی مدل REDMI 10A  دو سیم‌ کار...  6.714246
# 7224899    10 a  گوشی موبایل شیائومی مدل REDMI 10A  دو سیم‌ کار...  6.714246
# 7224899    10 a  گوشی موبایل شیائومی مدل REDMI 10A  دو سیم‌ کار...  6.714246
# 7224899    10 a  گوشی موبایل شیائومی مدل REDMI 10A  دو سیم‌ کار...  6.714246
# 7224899    10 a  گوشی موبایل شیائومی مدل REDMI 10A  دو سیم‌ کار...  6.714246
# 7224899    10 a  گوشی موبایل شیائومی مدل REDMI 10A  دو سیم‌ کار...  6.714246
#
#                        category_name  clicks  ctr_score  impressions  \
# p_id
# 7224899  کاپشن، بارانی و پالتو زنانه   104.0   0.319149        178.0
# 7224899  کاپشن، بارانی و پالتو زنانه   104.0   0.319149        178.0
# 7224899  کاپشن، بارانی و پالتو زنانه   104.0   0.319149        178.0
# 7224899  کاپشن، بارانی و پالتو زنانه   104.0   0.319149        178.0
# 7224899  کاپشن، بارانی و پالتو زنانه   104.0   0.319149        178.0
# 7224899  کاپشن، بارانی و پالتو زنانه   104.0   0.319149        178.0
# 7224899  کاپشن، بارانی و پالتو زنانه   104.0   0.319149        178.0
# 7224899  کاپشن، بارانی و پالتو زنانه   104.0   0.319149        178.0
# 7224899  کاپشن، بارانی و پالتو زنانه   104.0   0.319149        178.0
# 7224899  کاپشن، بارانی و پالتو زنانه   104.0   0.319149        178.0
#
#          log_normalized_candidate_score  mean_max_shops  min_price  \
# p_id
# 7224899                         1.00206            87.6    12000.0
# 7224899                         1.00206            87.6    12000.0
# 7224899                         1.00206            87.6    12000.0
# 7224899                         1.00206            87.6    12000.0
# 7224899                         1.00206            87.6    12000.0
# 7224899                         1.00206            87.6    12000.0
# 7224899                         1.00206            87.6    12000.0
# 7224899                         1.00206            87.6    12000.0
# 7224899                         1.00206            87.6    12000.0
# 7224899                         1.00206            87.6    12000.0
#
#                                                  new words popularity  \
# p_id
# 7224899  ['(کارتن', '10', 'اصلی)', '3', '4GB/64GB', '10...  unpopular
# 7224899  ['(کارتن', '10', 'اصلی)', '3', '4GB/64GB', '10...  unpopular
# 7224899  ['(کارتن', '10', 'اصلی)', '3', '4GB/64GB', '10...  unpopular
# 7224899  ['(کارتن', '10', 'اصلی)', '3', '4GB/64GB', '10...  unpopular
# 7224899  ['(کارتن', '10', 'اصلی)', '3', '4GB/64GB', '10...  unpopular
# 7224899  ['(کارتن', '10', 'اصلی)', '3', '4GB/64GB', '10...  unpopular
# 7224899  ['(کارتن', '10', 'اصلی)', '3', '4GB/64GB', '10...  unpopular
# 7224899  ['(کارتن', '10', 'اصلی)', '3', '4GB/64GB', '10...  unpopular
# 7224899  ['(کارتن', '10', 'اصلی)', '3', '4GB/64GB', '10...  unpopular
# 7224899  ['(کارتن', '10', 'اصلی)', '3', '4GB/64GB', '10...  unpopular
#
#              ctr            query_y  relevance
# p_id
# 7224899  0.58427               10 a          4
# 7224899  0.58427               10 c          1
# 7224899  0.58427               a 10          1
# 7224899  0.58427           redmi 10          1
# 7224899  0.58427         redmi 10 a          4
# 7224899  0.58427         redmi 10 c          1
# 7224899  0.58427            ردمی 10          1
# 7224899  0.58427          ردمی 10 a          4
# 7224899  0.58427          گوشی a 10          1
# 7224899  0.58427  گوشی شیایومی ردمی          2

# %%
# get score for index 1074166 in t_df
t_df.iloc[1]
# Out:
# query_x                                                               عطر جیبی
# p_des                             عطر مدادی جیبی جامد صابونی وارداتی و باکیفیت
# label                                                                 4.523562
# category_name                                      کاپشن، بارانی و پالتو زنانه
# clicks                                                                    22.0
# ctr_score                                                             0.029909
# impressions                                                              121.0
# log_normalized_candidate_score                                             1.0
# mean_max_shops                                                       16.389831
# min_price                                                              34000.0
# new words                                                            ['ushas']
# popularity                                                           unpopular
# ctr                                                                   0.181818
# query_y                                                               عطر جیبی
# relevance                                                                    4
# Name: 564, dtype: object

# %%
np.unique(t_df["relevance"].values, return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4], dtype=int64),
#  array([444347,   7845,   4329,   1563,   1593], dtype=int64))

# %%
# most relevant products return 100
t_df[t_df["relevance"] == 4].sort_values("ctr", ascending=False)[:100]
# Out:
#                query     p_id  \
# 275758         qt 82   148722
# 452042   galaxy m 52  1276659
# 19677           m 52  1276659
# 357203    شیشه فلاسک   361112
# 278085          2740   641840
# ...              ...      ...
# 7520        گوشی اپل  1013548
# 338757     اتو فلیپس    91519
# 276767  سبد پلاستیکی   665876
# 386006         اهمتر   451363
# 455466     گلوکزامین   229088
#
#                                                     p_des      label  \
# 275758  هندزفری بلوتوث دوگوش لنوو Lenovo QT82 (((ارسال...   4.392317
# 452042  گوشی موبایل سامسونگ مدل GALAXY M52 5G SM-M526B...   4.321928
# 19677   گوشی موبایل سامسونگ مدل GALAXY M52 5G SM-M526B...  10.051209
# 357203           انواع شیشه فلاسک از 75 تا 200 هزار تومان   4.392317
# 278085  دریل بتن کن رونیکس 40 میلی متری - 1250 وات - 7...   4.754888
# ...                                                   ...        ...
# 7520    گوشی اپل (استوک) iPhone 6s | حافظه 64 گیگابایت...   8.682995
# 338757  اتو بخار حرفه ای فیلیپس مدل GC4936 (غیر اصل هل...   3.000000
# 276767         سبد پلاستیکی RING رنگ سفید ۵۲۵(ساخت ‌ژاپن)   3.000000
# 386006   اهمتر-مولتی متر یاکسون MULTIMETER YAXUN  YX-890D   2.584963
# 455466  قرص روکشدار گلوکزامین 500 میلی گرم 50 عددی آوه...   2.584963
#
#                       category_name  clicks       ctr  impressions  \
# 275758  کاپشن، بارانی و پالتو زنانه    20.0  1.250000         16.0
# 452042  کاپشن، بارانی و پالتو زنانه    19.0  0.950000         20.0
# 19677   کاپشن، بارانی و پالتو زنانه  1060.0  0.923345       1148.0
# 357203  کاپشن، بارانی و پالتو زنانه    20.0  0.869565         23.0
# 278085  کاپشن، بارانی و پالتو زنانه    26.0  0.812500         32.0
# ...                             ...     ...       ...          ...
# 7520    کاپشن، بارانی و پالتو زنانه   410.0  0.282954       1449.0
# 338757  کاپشن، بارانی و پالتو زنانه     7.0  0.280000         25.0
# 276767  کاپشن، بارانی و پالتو زنانه     7.0  0.280000         25.0
# 386006  کاپشن، بارانی و پالتو زنانه     5.0  0.277778         18.0
# 455466  کاپشن، بارانی و پالتو زنانه     5.0  0.277778         18.0
#
#         log_normalized_candidate_score  mean_max_shops  min_price  \
# 275758                        1.016287       16.538462   238000.0
# 452042                        1.017420       34.764706  5249000.0
# 19677                         1.000135       20.576271  5249000.0
# 357203                        1.016287        2.728814    90000.0
# 278085                        1.011584       17.000000  5178450.0
# ...                                ...             ...        ...
# 7520                          1.000405       27.152542  2900000.0
# 338757                        1.068622       18.406780  2100000.0
# 276767                        1.068622        1.627119    39000.0
# 386006                        0.661642        1.016949   590000.0
# 455466                        0.721057        2.711111    46200.0
#
#                                                 new words popularity  \
# 275758  ['10', 'Bt', 'QT', 'رنگ', 'Earbuds', '2021', '...    popular
# 452042  ['مدلBLACK', '8)', '18', 'SM', '128گیگابایت-',...    popular
# 19677   ['مدلBLACK', '8)', '18', 'SM', '128گیگابایت-',...    popular
# 357203                                                 []  unpopular
# 278085  ['3', '۲۷۴۰', '–', 'کد', '5', 'شیار۱۲۴۰wپرقدرت...    popular
# ...                                                   ...        ...
# 7520    ['آیفون', 'iphone', 'گوشی\u200c', 'Smartphone'...  unpopular
# 338757  ['(PHILIPS)', 'دستی', 'هلندمونتاژ', '3000وات',...    popular
# 276767                                                 []  unpopular
# 386006                                                 []  unpopular
# 455466  ['غضروف', 'فلکس', 'Glucosamine', '|', '-', 'گر...    popular
#
#         relevance
# 275758          4
# 452042          4
# 19677           4
# 357203          4
# 278085          4
# ...           ...
# 7520            4
# 338757          4
# 276767          4
# 386006          4
# 455466          4
#
# [100 rows x 14 columns]

# %%
import joblib

# %%
# save with joblib
joblib.dump(t_df, "train_data_df.pkl")
# Out:
# ['train_data_df.pkl']

# %%
t_df.to_csv("train_data_df.csv")

# %%
merged_df = t_df.merge(relevance_df, on=['query', 'p_id'], how='left')

# %%
print(merged_df.isnull().sum())
# Out:
# query                                  0
# p_id                                   0
# p_des                                  0
# label                                  0
# category_name                          0
# clicks                                 0
# ctr                                    0
# impressions                            0
# log_normalized_candidate_score         0
# mean_max_shops                         0
# min_price                           7599
# new words                              0
# popularity                             0
# relevance_x                       459677
# relevance_y                       459677
# dtype: int64

# %%
t_df
# Out:
#                    query     p_id  \
# 0        لوستر سقفی برنز  6462477
# 1        لوستر سقفی برنز  7385791
# 2        لوستر سقفی برنز  3775536
# 3        لوستر سقفی برنز  1663988
# 4        لوستر سقفی برنز  6946932
# ...                  ...      ...
# 459672  همزن گوسونیک 407  8061315
# 459673  همزن گوسونیک 407   264504
# 459674  همزن گوسونیک 407  4273225
# 459675  همزن گوسونیک 407  6439966
# 459676  همزن گوسونیک 407  8180256
#
#                                                     p_des  label  \
# 0              لوستر سقفی چشمه نور 5 شعله کد C2542-B برنز    2.0
# 1             لوستر سقفی چشمه نور 3 شعله کد C2542/3B برنز    0.0
# 2                لوستر سقفی مدرن مدل نیلوفر سه تایی- سفید    0.0
# 3          لوستر سقفی کریستالی دایره سایز 25 مدل کارمانیا    0.0
# 4       لوستر سقفی کریستالی دایره سایز 25 دوبلکس مدل آداس    0.0
# ...                                                   ...    ...
# 459672  همزن گوسونیک مدل GSM-889 ا Gosonic GSM-889 Sta...    0.0
# 459673  همزن دستی گیربوکسی گاسونیک مدل 839 با پایه نگه...    0.0
# 459674  همزن کاسه دار حرفه ای برند گوسونیک مدل Gosonic...    0.0
# 459675  همزن برقی حرفه ای کاسه دار گوسونیک مدل Gosonic...    0.0
# 459676   طول سیم 0.7 متر محدوده توان مصرفی 300 تا 400 وات    0.0
#
#                       category_name  clicks       ctr  impressions  \
# 0       کاپشن، بارانی و پالتو زنانه     3.0  0.136364         22.0
# 1       کاپشن، بارانی و پالتو زنانه     0.0  0.000000         22.0
# 2       کاپشن، بارانی و پالتو زنانه     0.0  0.000000         18.0
# 3       کاپشن، بارانی و پالتو زنانه     0.0  0.000000         18.0
# 4       کاپشن، بارانی و پالتو زنانه     0.0  0.000000         18.0
# ...                             ...     ...       ...          ...
# 459672  کاپشن، بارانی و پالتو زنانه     0.0  0.000000         29.0
# 459673  کاپشن، بارانی و پالتو زنانه     0.0  0.000000         29.0
# 459674  کاپشن، بارانی و پالتو زنانه     0.0  0.000000         29.0
# 459675  کاپشن، بارانی و پالتو زنانه     0.0  0.000000         29.0
# 459676  کاپشن، بارانی و پالتو زنانه     0.0  0.000000         22.0
#
#         log_normalized_candidate_score  mean_max_shops  min_price  \
# 0                                  1.0        1.440678   821000.0
# 1                                  0.0        1.440678   792000.0
# 2                                  0.0        1.440678   400000.0
# 3                                  0.0        1.440678   756000.0
# 4                                  0.0        1.440678   756000.0
# ...                                ...             ...        ...
# 459672                             0.0       21.000000  2580000.0
# 459673                             0.0       21.000000   510000.0
# 459674                             0.0       21.000000  1040000.0
# 459675                             0.0       21.000000  3199000.0
# 459676                             0.0       21.000000   495000.0
#
#                                                 new words popularity  \
# 0                                                      []  unpopular
# 1                                                   ['۳']  unpopular
# 2                                                      []  unpopular
# 3                                                      []  unpopular
# 4                                                      []  unpopular
# ...                                                   ...        ...
# 459672  ['گاسونیک', 'W', 'gsm889', 'B', '۸۸۹', 'برقی',...  unpopular
# 459673  ['Gosonic', 'Mixer', 'برقی', 'برند', 'hand', '...    popular
# 459674  ['لیتر', '–', 'کاسه\u200cدار', 'کد', 'گاسونیک'...    popular
# 459675  ['8.5', 'electric', 'Mixer', 'GSM908', 'Stand'...  unpopular
# 459676  ['Gosonic', 'دستی', 'گاسونیک', '819', 'اصل', '...  unpopular
#
#         relevance
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 459672          0
# 459673          0
# 459674          0
# 459675          0
# 459676          0
#
# [459677 rows x 14 columns]

# %%
t_df = t_df.merge(relevance_df, on=["query", "p_id"], how="left")

# %%
t_df
# Out:
#                    query     p_id  \
# 0        لوستر سقفی برنز  6462477
# 1        لوستر سقفی برنز  7385791
# 2        لوستر سقفی برنز  3775536
# 3        لوستر سقفی برنز  1663988
# 4        لوستر سقفی برنز  6946932
# ...                  ...      ...
# 459672  همزن گوسونیک 407  8061315
# 459673  همزن گوسونیک 407   264504
# 459674  همزن گوسونیک 407  4273225
# 459675  همزن گوسونیک 407  6439966
# 459676  همزن گوسونیک 407  8180256
#
#                                                     p_des  label  \
# 0              لوستر سقفی چشمه نور 5 شعله کد C2542-B برنز    2.0
# 1             لوستر سقفی چشمه نور 3 شعله کد C2542/3B برنز    0.0
# 2                لوستر سقفی مدرن مدل نیلوفر سه تایی- سفید    0.0
# 3          لوستر سقفی کریستالی دایره سایز 25 مدل کارمانیا    0.0
# 4       لوستر سقفی کریستالی دایره سایز 25 دوبلکس مدل آداس    0.0
# ...                                                   ...    ...
# 459672  همزن گوسونیک مدل GSM-889 ا Gosonic GSM-889 Sta...    0.0
# 459673  همزن دستی گیربوکسی گاسونیک مدل 839 با پایه نگه...    0.0
# 459674  همزن کاسه دار حرفه ای برند گوسونیک مدل Gosonic...    0.0
# 459675  همزن برقی حرفه ای کاسه دار گوسونیک مدل Gosonic...    0.0
# 459676   طول سیم 0.7 متر محدوده توان مصرفی 300 تا 400 وات    0.0
#
#                       category_name  clicks       ctr  impressions  \
# 0       کاپشن، بارانی و پالتو زنانه     3.0  0.136364         22.0
# 1       کاپشن، بارانی و پالتو زنانه     0.0  0.000000         22.0
# 2       کاپشن، بارانی و پالتو زنانه     0.0  0.000000         18.0
# 3       کاپشن، بارانی و پالتو زنانه     0.0  0.000000         18.0
# 4       کاپشن، بارانی و پالتو زنانه     0.0  0.000000         18.0
# ...                             ...     ...       ...          ...
# 459672  کاپشن، بارانی و پالتو زنانه     0.0  0.000000         29.0
# 459673  کاپشن، بارانی و پالتو زنانه     0.0  0.000000         29.0
# 459674  کاپشن، بارانی و پالتو زنانه     0.0  0.000000         29.0
# 459675  کاپشن، بارانی و پالتو زنانه     0.0  0.000000         29.0
# 459676  کاپشن، بارانی و پالتو زنانه     0.0  0.000000         22.0
#
#         log_normalized_candidate_score  mean_max_shops  min_price  \
# 0                                  1.0        1.440678   821000.0
# 1                                  0.0        1.440678   792000.0
# 2                                  0.0        1.440678   400000.0
# 3                                  0.0        1.440678   756000.0
# 4                                  0.0        1.440678   756000.0
# ...                                ...             ...        ...
# 459672                             0.0       21.000000  2580000.0
# 459673                             0.0       21.000000   510000.0
# 459674                             0.0       21.000000  1040000.0
# 459675                             0.0       21.000000  3199000.0
# 459676                             0.0       21.000000   495000.0
#
#                                                 new words popularity  level_0  \
# 0                                                      []  unpopular      NaN
# 1                                                   ['۳']  unpopular      NaN
# 2                                                      []  unpopular      NaN
# 3                                                      []  unpopular      NaN
# 4                                                      []  unpopular      NaN
# ...                                                   ...        ...      ...
# 459672  ['گاسونیک', 'W', 'gsm889', 'B', '۸۸۹', 'برقی',...  unpopular      NaN
# 459673  ['Gosonic', 'Mixer', 'برقی', 'برند', 'hand', '...    popular      NaN
# 459674  ['لیتر', '–', 'کاسه\u200cدار', 'کد', 'گاسونیک'...    popular      NaN
# 459675  ['8.5', 'electric', 'Mixer', 'GSM908', 'Stand'...  unpopular      NaN
# 459676  ['Gosonic', 'دستی', 'گاسونیک', '819', 'اصل', '...  unpopular      NaN
#
#         index  relevance
# 0         NaN        NaN
# 1         NaN        NaN
# 2         NaN        NaN
# 3         NaN        NaN
# 4         NaN        NaN
# ...       ...        ...
# 459672    NaN        NaN
# 459673    NaN        NaN
# 459674    NaN        NaN
# 459675    NaN        NaN
# 459676    NaN        NaN
#
# [459677 rows x 16 columns]

# %%
# show 10 products with the highest relevance score
np.unique(merged_df["relevance"].values, return_counts=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\amkyp\anaconda3\envs\wsd_bert\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\amkyp\anaconda3\envs\wsd_bert\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\amkyp\anaconda3\envs\wsd_bert\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'relevance'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[207], line 2
#       1 # show 10 products with the highest relevance score
# ----> 2 np.unique(merged_df["relevance"].values, return_counts=True)
#
# File c:\Users\amkyp\anaconda3\envs\wsd_bert\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\Users\amkyp\anaconda3\envs\wsd_bert\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'relevance'

# %%
# remove the temporary ctr column
# temp_df.drop("ctr", axis=1, inplace=True)

# %%
def handle_zero_division(func):
    """Handle zero division error and return 0 instead of nan."""
    def wrapper(*args, **kwargs):
        try:
            result = func(*args, **kwargs)
        except ZeroDivisionError:
            result = '0'
        return result
    return wrapper

def handle_type_error(func):
    """Handle type error and return 0 instead of nan."""
    def wrapper(*args, **kwargs):
        try:
            result = func(*args, **kwargs)
        except TypeError:
            result = '0'
        return result
    return wrapper

@handle_zero_division
@handle_type_error
def calculate_relevance(x):
    return np.ceil(4 * x["ctr"] / np.max(x["ctr"]))

test_df = pd.DataFrame({'group': ['A', 'A', 'B', 'B'], 'ctr': [1, 2, 3, 0]})
grouped = test_df.groupby('group')
print(grouped.get_group('B'))

# %%
print(calculate_relevance(grouped.get_group('B')))

# %%
test_df["relevance"] = 0

# %%
try:
    test["relevance"] = grouped.apply(lambda x: np.ceil(4 * x["ctr"] / np.max(x["ctr"])))
except TypeError as e:
    if str(e) == "incompatible index of inserted column with frame index":
        print("Caught the 'incompatible index of inserted column with frame index' error")
    else:
        raise e

# %%
try:
    test_df["relevance"] = grouped.apply(lambda x: np.ceil(4 * x["ctr"] / np.max(x["ctr"])))
except (ZeroDivisionError, TypeError) as e:
    # Handle the exception here
    print("An error occurred:", e)
